# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import csv, sqlite3

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df = pd.read_csv('aus_real_estate.csv')

# %%
df.head()
# Out:
#      Price  Bedrooms  Bathrooms  SqFt       City State  Year_Built       Type  \
# 0   982112         4          1  1561   Adelaide   QLD        2021  Townhouse
# 1   571388         3          2  3735  Melbourne   VIC        1999      House
# 2   866821         5          1  2032     Sydney   VIC        1976  Townhouse
# 3  1230977         4          3  3861   Brisbane    SA        1978      House
# 4   241787         4          2  3150      Perth    SA        1992  Apartment
#
#    Garage  Lot_Area
# 0       0      1357
# 1       1      8397
# 2       0      3478
# 3       0      7619
# 4       0      8324

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Price       5000 non-null   int64
#  1   Bedrooms    5000 non-null   int64
#  2   Bathrooms   5000 non-null   int64
#  3   SqFt        5000 non-null   int64
#  4   City        5000 non-null   object
#  5   State       5000 non-null   object
#  6   Year_Built  5000 non-null   int64
#  7   Type        5000 non-null   object
#  8   Garage      5000 non-null   int64
#  9   Lot_Area    5000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 390.8+ KB

# %%
df.isnull().sum()
# Out:
# Price         0
# Bedrooms      0
# Bathrooms     0
# SqFt          0
# City          0
# State         0
# Year_Built    0
# Type          0
# Garage        0
# Lot_Area      0
# dtype: int64

# %%
len(df)

df.head()
# Out:
#      Price  Bedrooms  Bathrooms  SqFt       City State  Year_Built       Type  \
# 0   982112         4          1  1561   Adelaide   QLD        2021  Townhouse
# 1   571388         3          2  3735  Melbourne   VIC        1999      House
# 2   866821         5          1  2032     Sydney   VIC        1976  Townhouse
# 3  1230977         4          3  3861   Brisbane    SA        1978      House
# 4   241787         4          2  3150      Perth    SA        1992  Apartment
#
#    Garage  Lot_Area
# 0       0      1357
# 1       1      8397
# 2       0      3478
# 3       0      7619
# 4       0      8324

# %%
df_cleaned = df.dropna()

# %%
len(df_cleaned)
# Out:
# 5000

# %%
max_value =  df_cleaned['Price'].max()
max_value
# Out:
# 1999701

# %%
df_cleaned['PriceSegment'] = pd.cut(df_cleaned['Price'],bins = [0, 5000, 100000, 1000000, np.inf], 
                                 labels = ['Affordable', 'Mid-range', 'High-end', 'Luxury']
)


city_area = ['Sydney','Melbourne','Brisbane']
df_city = df_cleaned[df_cleaned['City'].isin(city_area)]

# %%
df_city = df_city[['City','State','SqFt','Bedrooms','Bathrooms','Price','PriceSegment']]
df_city
# Out:
#            City State  SqFt  Bedrooms  Bathrooms    Price PriceSegment
# 1     Melbourne   VIC  3735         3          2   571388     High-end
# 2        Sydney   VIC  2032         5          1   866821     High-end
# 3      Brisbane    SA  3861         4          3  1230977       Luxury
# 5      Brisbane    SA  1923         4          2   631871     High-end
# 7      Brisbane   QLD  2447         1          1  1509971       Luxury
# ...         ...   ...   ...       ...        ...      ...          ...
# 4992     Sydney    WA  2275         3          3  1877774       Luxury
# 4994   Brisbane    WA  3399         4          2   951568     High-end
# 4996   Brisbane   QLD  1117         3          1  1634457       Luxury
# 4998     Sydney   QLD  1825         3          3  1976680       Luxury
# 4999   Brisbane    SA  2103         2          2  1470344       Luxury
#
# [2972 rows x 7 columns]

# %%
con = sqlite3.connect('AU_HousePrice.db')
cur = con.cursor()

# %%
# %load_ext sql

# %%
# %sql sqlite:///AU_HousePrice.db

# %%
df_city.to_sql('CityArea',con,if_exists = 'replace',index = False)
# Out:
# 2972

# %%
# %%sql
# SELECT *
# FROM CityArea
# WHERE [Price] >= 1000000
# Out:
#  * sqlite:///AU_HousePrice.db
# Done.
# [('Brisbane', 'SA', 3861, 4, 3, 1230977, 'Luxury'),
#  ('Brisbane', 'QLD', 2447, 1, 1, 1509971, 'Luxury'),
#  ('Melbourne', 'NSW', 1842, 5, 3, 1453282, 'Luxury'),
#  ('Melbourne', 'NSW', 810, 4, 2, 1476267, 'Luxury'),
#  ('Brisbane', 'QLD', 2231, 3, 3, 1726874, 'Luxury'),
#  ('Melbourne', 'VIC', 2890, 4, 1, 1358342, 'Luxury'),
#  ('Melbourne', 'SA', 2845, 4, 2, 1712788, 'Luxury'),
#  ('Melbourne', 'SA', 1440, 5, 1, 1874185, 'Luxury'),
#  ('Sydney', 'SA', 2619, 2, 2, 1183917, 'Luxury'),
#  ('Brisbane', 'SA', 1180, 4, 2, 1961716, 'Luxury'),
#  ('Brisbane', 'SA', 3253, 1, 3, 1862030, 'Luxury'),
#  ('Melbourne', 'QLD', 1662, 3, 2, 1770580, 'Luxury'),
#  ('Melbourne', 'VIC', 3538, 3, 1, 1813465, 'Luxury'),
#  ('Brisbane', 'NSW', 1710, 3, 1, 1938851, 'Luxury'),
#  ('Brisbane', 'NSW', 3612, 4, 2, 1794143, 'Luxury'),
#  ('Sydney', 'VIC', 3578, 2, 3, 1358111, 'Luxury'),
#  ('Brisbane', 'VIC', 2681, 4, 1, 1689550, 'Luxury'),
#  ('Brisbane', 'WA', 2597, 2, 3, 1962708, 'Luxury'),
#  ('Brisbane', 'WA', 1392, 4, 2, 1403566, 'Luxury'),
#  ('Sydney', 'NSW', 3121, 1, 1, 1766096, 'Luxury'),
#  ('Sydney', 'NSW', 1972, 2, 2, 1551243, 'Luxury'),
#  ('Melbourne', 'WA', 2922, 5, 3, 1851710, 'Luxury'),
#  ('Brisbane', 'NSW', 2677, 3, 2, 1159775, 'Luxury'),
#  ('Sydney', 'NSW', 2083, 4, 2, 1595992, 'Luxury'),
#  ('Brisbane', 'VIC', 2033, 5, 2, 1943494, 'Luxury'),
#  ('Sydney', 'SA', 3946, 1, 1, 1257454, 'Luxury'),
#  ('Sydney', 'NSW', 2516, 5, 3, 1656027, 'Luxury'),
#  ('Brisbane', 'WA', 3381, 2, 2, 1978166, 'Luxury'),
#  ('Brisbane', 'VIC', 2651, 3, 3, 1009383, 'Luxury'),
#  ('Brisbane', 'VIC', 1532, 1, 2, 1121178, 'Luxury'),
#  ('Brisbane', 'NSW', 3909, 3, 3, 1538306, 'Luxury'),
#  ('Sydney', 'WA', 1435, 3, 2, 1853162, 'Luxury'),
#  ('Melbourne', 'WA', 1832, 2, 1, 1978401, 'Luxury'),
#  ('Sydney', 'WA', 1374, 1, 3, 1155345, 'Luxury'),
#  ('Sydney', 'WA', 1216, 4, 1, 1243874, 'Luxury'),
#  ('Brisbane', 'WA', 3938, 2, 2, 1023056, 'Luxury'),
#  ('Brisbane', 'SA', 2718, 2, 3, 1246896, 'Luxury'),
#  ('Sydney', 'QLD', 1886, 2, 3, 1553757, 'Luxury'),
#  ('Sydney', 'NSW', 1072, 1, 2, 1830398, 'Luxury'),
#  ('Sydney', 'WA', 3024, 4, 3, 1747076, 'Luxury'),
#  ('Melbourne', 'SA', 3934, 3, 1, 1376166, 'Luxury'),
#  ('Sydney', 'NSW', 836, 1, 2, 1997428, 'Luxury'),
#  ('Sydney', 'VIC', 1271, 1, 2, 1713337, 'Luxury'),
#  ('Brisbane', 'NSW', 3151, 5, 2, 1269074, 'Luxury'),
#  ('Brisbane', 'NSW', 1046, 3, 2, 1822894, 'Luxury'),
#  ('Brisbane', 'SA', 3298, 1, 2, 1767651, 'Luxury'),
#  ('Sydney', 'WA', 1455, 2, 3, 1618489, 'Luxury'),
#  ('Melbourne', 'VIC', 3583, 1, 2, 1687337, 'Luxury'),
#  ('Brisbane', 'WA', 3872, 5, 1, 1400552, 'Luxury'),
#  ('Brisbane', 'QLD', 1137, 2, 2, 1453068, 'Luxury'),
#  ('Brisbane', 'QLD', 3117, 1, 1, 1696634, 'Luxury'),
#  ('Sydney', 'VIC', 2658, 3, 3, 1478180, 'Luxury'),
#  ('Brisbane', 'SA', 1925, 4, 2, 1336765, 'Luxury'),
#  ('Sydney', 'VIC', 975, 5, 2, 1455928, 'Luxury'),
#  ('Sydney', 'VIC', 2650, 4, 3, 1994100, 'Luxury'),
#  ('Brisbane', 'NSW', 1540, 1, 2, 1683509, 'Luxury'),
#  ('Melbourne', 'VIC', 1186, 3, 2, 1248848, 'Luxury'),
#  ('Melbourne', 'VIC', 3071, 3, 2, 1680538, 'Luxury'),
#  ('Brisbane', 'WA', 3524, 2, 2, 1962529, 'Luxury'),
#  ('Sydney', 'WA', 818, 2, 3, 1023653, 'Luxury'),
#  ('Brisbane', 'VIC', 2617, 4, 1, 1782276, 'Luxury'),
#  ('Melbourne', 'WA', 1507, 4, 3, 1481585, 'Luxury'),
#  ('Melbourne', 'VIC', 3586, 5, 2, 1971270, 'Luxury'),
#  ('Brisbane', 'WA', 1030, 5, 2, 1334505, 'Luxury'),
#  ('Melbourne', 'QLD', 2593, 1, 2, 1714157, 'Luxury'),
#  ('Melbourne', 'VIC', 3681, 2, 2, 1785364, 'Luxury'),
#  ('Sydney', 'QLD', 2233, 2, 3, 1065724, 'Luxury'),
#  ('Melbourne', 'SA', 1041, 1, 2, 1135068, 'Luxury'),
#  ('Brisbane', 'VIC', 882, 5, 1, 1101444, 'Luxury'),
#  ('Sydney', 'SA', 3382, 3, 3, 1742958, 'Luxury'),
#  ('Brisbane', 'WA', 2955, 3, 1, 1182226, 'Luxury'),
#  ('Melbourne', 'NSW', 3627, 4, 3, 1173216, 'Luxury'),
#  ('Sydney', 'WA', 1124, 5, 3, 1559537, 'Luxury'),
#  ('Melbourne', 'VIC', 3578, 3, 2, 1597649, 'Luxury'),
#  ('Brisbane', 'SA', 3350, 3, 3, 1372458, 'Luxury'),
#  ('Sydney', 'WA', 3627, 3, 2, 1850634, 'Luxury'),
#  ('Melbourne', 'NSW', 2170, 2, 2, 1670329, 'Luxury'),
#  ('Brisbane', 'VIC', 3390, 1, 1, 1912077, 'Luxury'),
#  ('Melbourne', 'QLD', 3349, 1, 2, 1659103, 'Luxury'),
#  ('Melbourne', 'NSW', 1220, 5, 1, 1209135, 'Luxury'),
#  ('Brisbane', 'WA', 2164, 2, 1, 1239053, 'Luxury'),
#  ('Brisbane', 'SA', 1701, 5, 1, 1531855, 'Luxury'),
#  ('Melbourne', 'VIC', 1749, 5, 3, 1159095, 'Luxury'),
#  ('Brisbane', 'WA', 1639, 5, 2, 1299402, 'Luxury'),
#  ('Melbourne', 'NSW', 1528, 3, 1, 1494787, 'Luxury'),
#  ('Brisbane', 'SA', 2232, 2, 1, 1739814, 'Luxury'),
#  ('Sydney', 'SA', 2038, 2, 1, 1857564, 'Luxury'),
#  ('Sydney', 'QLD', 2033, 5, 2, 1918577, 'Luxury'),
#  ('Sydney', 'SA', 3941, 1, 2, 1387504, 'Luxury'),
#  ('Sydney', 'WA', 1242, 1, 1, 1980088, 'Luxury'),
#  ('Sydney', 'SA', 3157, 5, 2, 1249547, 'Luxury'),
#  ('Sydney', 'WA', 2213, 1, 1, 1276634, 'Luxury'),
#  ('Sydney', 'WA', 1688, 4, 1, 1852006, 'Luxury'),
#  ('Brisbane', 'QLD', 844, 5, 1, 1388096, 'Luxury'),
#  ('Melbourne', 'WA', 3517, 3, 1, 1020591, 'Luxury'),
#  ('Melbourne', 'SA', 2129, 3, 2, 1202772, 'Luxury'),
#  ('Melbourne', 'SA', 1723, 3, 3, 1575894, 'Luxury'),
#  ('Sydney', 'VIC', 3859, 5, 2, 1063911, 'Luxury'),
#  ('Brisbane', 'NSW', 2300, 4, 2, 1508480, 'Luxury'),
#  ('Sydney', 'WA', 1716, 2, 2, 1214226, 'Luxury'),
#  ('Melbourne', 'SA', 1610, 2, 2, 1303377, 'Luxury'),
#  ('Brisbane', 'QLD', 3959, 5, 3, 1651258, 'Luxury'),
#  ('Brisbane', 'NSW', 1619, 3, 2, 1896198, 'Luxury'),
#  ('Melbourne', 'WA', 1251, 1, 1, 1630122, 'Luxury'),
#  ('Sydney', 'WA', 3041, 3, 2, 1497681, 'Luxury'),
#  ('Melbourne', 'QLD', 1685, 2, 2, 1969642, 'Luxury'),
#  ('Melbourne', 'WA', 1231, 1, 3, 1989872, 'Luxury'),
#  ('Sydney', 'NSW', 3731, 1, 2, 1269204, 'Luxury'),
#  ('Sydney', 'NSW', 3029, 5, 3, 1232519, 'Luxury'),
#  ('Melbourne', 'WA', 2842, 1, 2, 1565333, 'Luxury'),
#  ('Brisbane', 'WA', 3966, 2, 3, 1325268, 'Luxury'),
#  ('Brisbane', 'QLD', 3664, 4, 3, 1317338, 'Luxury'),
#  ('Sydney', 'QLD', 1285, 4, 3, 1353969, 'Luxury'),
#  ('Brisbane', 'VIC', 1666, 5, 1, 1684778, 'Luxury'),
#  ('Sydney', 'VIC', 1485, 3, 1, 1982171, 'Luxury'),
#  ('Brisbane', 'SA', 2611, 3, 1, 1749543, 'Luxury'),
#  ('Melbourne', 'VIC', 2561, 4, 2, 1561505, 'Luxury'),
#  ('Melbourne', 'VIC', 2138, 4, 3, 1579789, 'Luxury'),
#  ('Melbourne', 'VIC', 3601, 5, 2, 1659465, 'Luxury'),
#  ('Sydney', 'NSW', 2601, 1, 3, 1287154, 'Luxury'),
#  ('Melbourne', 'WA', 945, 2, 2, 1497793, 'Luxury'),
#  ('Sydney', 'WA', 3742, 2, 2, 1427339, 'Luxury'),
#  ('Brisbane', 'SA', 1263, 5, 1, 1695680, 'Luxury'),
#  ('Sydney', 'VIC', 3315, 3, 1, 1635922, 'Luxury'),
#  ('Melbourne', 'SA', 2542, 4, 3, 1293839, 'Luxury'),
#  ('Sydney', 'NSW', 1574, 3, 2, 1051600, 'Luxury'),
#  ('Melbourne', 'NSW', 3129, 3, 2, 1972667, 'Luxury'),
#  ('Brisbane', 'VIC', 1285, 2, 2, 1503376, 'Luxury'),
#  ('Melbourne', 'QLD', 1215, 5, 2, 1046867, 'Luxury'),
#  ('Melbourne', 'QLD', 1393, 2, 2, 1156375, 'Luxury'),
#  ('Sydney', 'WA', 2668, 4, 3, 1169886, 'Luxury'),
#  ('Melbourne', 'NSW', 1867, 5, 3, 1932019, 'Luxury'),
#  ('Brisbane', 'SA', 1515, 2, 1, 1483672, 'Luxury'),
#  ('Sydney', 'QLD', 1525, 4, 3, 1003707, 'Luxury'),
#  ('Sydney', 'NSW', 1281, 2, 1, 1280445, 'Luxury'),
#  ('Melbourne', 'QLD', 2419, 5, 3, 1701884, 'Luxury'),
#  ('Brisbane', 'VIC', 915, 3, 3, 1539211, 'Luxury'),
#  ('Sydney', 'SA', 3095, 1, 1, 1900936, 'Luxury'),
#  ('Sydney', 'NSW', 3595, 5, 3, 1535472, 'Luxury'),
#  ('Sydney', 'SA', 1613, 4, 1, 1760308, 'Luxury'),
#  ('Melbourne', 'NSW', 2396, 1, 2, 1962812, 'Luxury'),
#  ('Sydney', 'SA', 1183, 1, 2, 1820338, 'Luxury'),
#  ('Melbourne', 'NSW', 2708, 1, 2, 1018736, 'Luxury'),
#  ('Sydney', 'NSW', 2343, 1, 3, 1212949, 'Luxury'),
#  ('Brisbane', 'SA', 3008, 3, 1, 1236249, 'Luxury'),
#  ('Brisbane', 'SA', 1176, 3, 1, 1079460, 'Luxury'),
#  ('Melbourne', 'VIC', 2829, 5, 2, 1316680, 'Luxury'),
#  ('Sydney', 'QLD', 3842, 5, 1, 1812742, 'Luxury'),
#  ('Brisbane', 'NSW', 888, 5, 2, 1685241, 'Luxury'),
#  ('Melbourne', 'WA', 2019, 3, 1, 1102740, 'Luxury'),
#  ('Brisbane', 'NSW', 2131, 1, 3, 1607190, 'Luxury'),
#  ('Sydney', 'WA', 1610, 2, 2, 1268596, 'Luxury'),
#  ('Melbourne', 'SA', 3121, 2, 2, 1069848, 'Luxury'),
#  ('Melbourne', 'QLD', 1692, 5, 3, 1471612, 'Luxury'),
#  ('Sydney', 'WA', 3920, 4, 1, 1070430, 'Luxury'),
#  ('Melbourne', 'VIC', 3046, 5, 3, 1374076, 'Luxury'),
#  ('Sydney', 'SA', 3837, 4, 3, 1362699, 'Luxury'),
#  ('Sydney', 'QLD', 1102, 5, 1, 1688847, 'Luxury'),
#  ('Brisbane', 'QLD', 1236, 3, 3, 1095986, 'Luxury'),
#  ('Melbourne', 'SA', 1760, 2, 2, 1361972, 'Luxury'),
#  ('Melbourne', 'SA', 1196, 3, 2, 1948661, 'Luxury'),
#  ('Brisbane', 'QLD', 1473, 5, 3, 1296884, 'Luxury'),
#  ('Sydney', 'VIC', 1065, 2, 2, 1608161, 'Luxury'),
#  ('Brisbane', 'SA', 919, 1, 3, 1392228, 'Luxury'),
#  ('Sydney', 'QLD', 3761, 2, 2, 1734939, 'Luxury'),
#  ('Sydney', 'WA', 1142, 2, 2, 1004994, 'Luxury'),
#  ('Sydney', 'NSW', 1318, 1, 2, 1860111, 'Luxury'),
#  ('Melbourne', 'SA', 2805, 1, 2, 1511740, 'Luxury'),
#  ('Brisbane', 'SA', 1513, 1, 3, 1385790, 'Luxury'),
#  ('Brisbane', 'WA', 3393, 2, 3, 1347515, 'Luxury'),
#  ('Sydney', 'QLD', 2808, 5, 1, 1723117, 'Luxury'),
#  ('Brisbane', 'NSW', 858, 2, 1, 1436123, 'Luxury'),
#  ('Brisbane', 'WA', 3271, 1, 2, 1146953, 'Luxury'),
#  ('Sydney', 'WA', 3430, 4, 2, 1281384, 'Luxury'),
#  ('Sydney', 'VIC', 1376, 5, 2, 1903593, 'Luxury'),
#  ('Brisbane', 'SA', 2829, 3, 2, 1660650, 'Luxury'),
#  ('Brisbane', 'WA', 1610, 4, 1, 1008994, 'Luxury'),
#  ('Sydney', 'SA', 2975, 5, 1, 1500413, 'Luxury'),
#  ('Melbourne', 'QLD', 2360, 1, 1, 1195913, 'Luxury'),
#  ('Melbourne', 'QLD', 3492, 4, 1, 1126788, 'Luxury'),
#  ('Brisbane', 'QLD', 2863, 4, 1, 1246965, 'Luxury'),
#  ('Sydney', 'VIC', 2950, 5, 3, 1518924, 'Luxury'),
#  ('Melbourne', 'WA', 2431, 1, 2, 1726888, 'Luxury'),
#  ('Brisbane', 'QLD', 1026, 1, 3, 1418151, 'Luxury'),
#  ('Melbourne', 'NSW', 3523, 2, 2, 1850497, 'Luxury'),
#  ('Sydney', 'WA', 3960, 1, 3, 1274320, 'Luxury'),
#  ('Sydney', 'WA', 3738, 1, 3, 1716112, 'Luxury'),
#  ('Melbourne', 'NSW', 2311, 2, 1, 1239160, 'Luxury'),
#  ('Melbourne', 'WA', 1350, 4, 3, 1842817, 'Luxury'),
#  ('Brisbane', 'SA', 848, 3, 1, 1457727, 'Luxury'),
#  ('Brisbane', 'VIC', 1636, 1, 2, 1030689, 'Luxury'),
#  ('Melbourne', 'WA', 1332, 3, 3, 1317111, 'Luxury'),
#  ('Brisbane', 'WA', 3179, 1, 1, 1421223, 'Luxury'),
#  ('Sydney', 'VIC', 2143, 4, 2, 1748221, 'Luxury'),
#  ('Brisbane', 'VIC', 2347, 5, 3, 1419158, 'Luxury'),
#  ('Sydney', 'QLD', 1306, 5, 1, 1778413, 'Luxury'),
#  ('Brisbane', 'QLD', 1231, 5, 1, 1429496, 'Luxury'),
#  ('Melbourne', 'VIC', 1018, 4, 1, 1691759, 'Luxury'),
#  ('Melbourne', 'NSW', 1976, 5, 3, 1622452, 'Luxury'),
#  ('Brisbane', 'SA', 2948, 1, 2, 1723683, 'Luxury'),
#  ('Brisbane', 'VIC', 3425, 1, 1, 1855706, 'Luxury'),
#  ('Sydney', 'WA', 3221, 4, 3, 1808984, 'Luxury'),
#  ('Brisbane', 'VIC', 1571, 2, 1, 1294391, 'Luxury'),
#  ('Brisbane', 'QLD', 3416, 4, 2, 1839169, 'Luxury'),
#  ('Melbourne', 'WA', 1487, 5, 2, 1248770, 'Luxury'),
#  ('Brisbane', 'QLD', 2445, 2, 2, 1210828, 'Luxury'),
#  ('Sydney', 'NSW', 1448, 4, 2, 1011191, 'Luxury'),
#  ('Sydney', 'QLD', 970, 2, 3, 1347255, 'Luxury'),
#  ('Brisbane', 'QLD', 3797, 3, 3, 1347052, 'Luxury'),
#  ('Brisbane', 'QLD', 1934, 3, 3, 1093553, 'Luxury'),
#  ('Brisbane', 'VIC', 1600, 5, 1, 1025664, 'Luxury'),
#  ('Sydney', 'NSW', 817, 3, 2, 1930093, 'Luxury'),
#  ('Melbourne', 'SA', 2722, 1, 2, 1615931, 'Luxury'),
#  ('Brisbane', 'VIC', 2564, 4, 1, 1279127, 'Luxury'),
#  ('Melbourne', 'VIC', 2739, 5, 3, 1599349, 'Luxury'),
#  ('Melbourne', 'NSW', 1525, 1, 2, 1138279, 'Luxury'),
#  ('Melbourne', 'QLD', 938, 3, 2, 1726837, 'Luxury'),
#  ('Melbourne', 'VIC', 1020, 4, 1, 1193599, 'Luxury'),
#  ('Brisbane', 'WA', 3001, 5, 2, 1134793, 'Luxury'),
#  ('Melbourne', 'VIC', 2819, 1, 2, 1198853, 'Luxury'),
#  ('Melbourne', 'QLD', 988, 3, 3, 1899286, 'Luxury'),
#  ('Sydney', 'VIC', 2758, 4, 3, 1425299, 'Luxury'),
#  ('Brisbane', 'SA', 902, 3, 2, 1796132, 'Luxury'),
#  ('Melbourne', 'VIC', 1619, 4, 2, 1911808, 'Luxury'),
#  ('Sydney', 'NSW', 3760, 4, 2, 1278506, 'Luxury'),
#  ('Melbourne', 'SA', 3639, 5, 2, 1792093, 'Luxury'),
#  ('Brisbane', 'WA', 2894, 4, 1, 1922653, 'Luxury'),
#  ('Brisbane', 'SA', 3288, 2, 3, 1006801, 'Luxury'),
#  ('Brisbane', 'VIC', 2794, 5, 1, 1928634, 'Luxury'),
#  ('Melbourne', 'NSW', 1101, 2, 2, 1674795, 'Luxury'),
#  ('Brisbane', 'SA', 3180, 5, 2, 1764293, 'Luxury'),
#  ('Melbourne', 'NSW', 1553, 5, 1, 1540099, 'Luxury'),
#  ('Melbourne', 'SA', 3906, 5, 1, 1134757, 'Luxury'),
#  ('Melbourne', 'NSW', 1389, 2, 1, 1872180, 'Luxury'),
#  ('Melbourne', 'SA', 3021, 3, 3, 1833961, 'Luxury'),
#  ('Melbourne', 'QLD', 2213, 4, 2, 1827565, 'Luxury'),
#  ('Sydney', 'WA', 2130, 3, 2, 1745848, 'Luxury'),
#  ('Melbourne', 'SA', 3457, 5, 2, 1422385, 'Luxury'),
#  ('Sydney', 'VIC', 2530, 5, 2, 1249836, 'Luxury'),
#  ('Sydney', 'SA', 885, 4, 1, 1690098, 'Luxury'),
#  ('Brisbane', 'NSW', 1858, 5, 2, 1848338, 'Luxury'),
#  ('Melbourne', 'VIC', 806, 1, 1, 1545246, 'Luxury'),
#  ('Sydney', 'WA', 1100, 1, 2, 1246039, 'Luxury'),
#  ('Sydney', 'VIC', 2537, 3, 1, 1426801, 'Luxury'),
#  ('Melbourne', 'QLD', 3257, 5, 1, 1815961, 'Luxury'),
#  ('Brisbane', 'QLD', 994, 3, 3, 1424428, 'Luxury'),
#  ('Melbourne', 'SA', 3566, 1, 2, 1232917, 'Luxury'),
#  ('Brisbane', 'NSW', 2207, 1, 3, 1263955, 'Luxury'),
#  ('Sydney', 'SA', 3285, 1, 3, 1827285, 'Luxury'),
#  ('Sydney', 'QLD', 3925, 5, 2, 1559732, 'Luxury'),
#  ('Melbourne', 'VIC', 1839, 5, 1, 1636206, 'Luxury'),
#  ('Brisbane', 'WA', 1589, 1, 2, 1664538, 'Luxury'),
#  ('Sydney', 'QLD', 3609, 2, 2, 1316418, 'Luxury'),
#  ('Sydney', 'WA', 3974, 2, 1, 1586190, 'Luxury'),
#  ('Brisbane', 'QLD', 3387, 1, 3, 1305702, 'Luxury'),
#  ('Sydney', 'QLD', 1673, 5, 1, 1115285, 'Luxury'),
#  ('Melbourne', 'WA', 1524, 2, 3, 1187403, 'Luxury'),
#  ('Melbourne', 'QLD', 1970, 1, 2, 1602870, 'Luxury'),
#  ('Brisbane', 'VIC', 3939, 3, 3, 1891953, 'Luxury'),
#  ('Sydney', 'QLD', 1566, 4, 3, 1488796, 'Luxury'),
#  ('Melbourne', 'NSW', 2381, 3, 3, 1817005, 'Luxury'),
#  ('Brisbane', 'NSW', 1694, 1, 2, 1329708, 'Luxury'),
#  ('Brisbane', 'QLD', 3827, 3, 2, 1111590, 'Luxury'),
#  ('Sydney', 'SA', 2211, 4, 3, 1089748, 'Luxury'),
#  ('Melbourne', 'VIC', 3772, 1, 1, 1509270, 'Luxury'),
#  ('Melbourne', 'VIC', 3456, 4, 3, 1200247, 'Luxury'),
#  ('Melbourne', 'SA', 3645, 1, 2, 1976953, 'Luxury'),
#  ('Brisbane', 'WA', 1922, 2, 1, 1344109, 'Luxury'),
#  ('Brisbane', 'VIC', 978, 3, 1, 1762632, 'Luxury'),
#  ('Sydney', 'WA', 1801, 5, 3, 1658649, 'Luxury'),
#  ('Melbourne', 'SA', 1305, 2, 2, 1222327, 'Luxury'),
#  ('Melbourne', 'WA', 1206, 3, 3, 1704257, 'Luxury'),
#  ('Melbourne', 'NSW', 3723, 4, 2, 1848250, 'Luxury'),
#  ('Melbourne', 'WA', 3519, 2, 3, 1893366, 'Luxury'),
#  ('Sydney', 'SA', 1019, 1, 3, 1825467, 'Luxury'),
#  ('Brisbane', 'QLD', 3166, 3, 1, 1277187, 'Luxury'),
#  ('Brisbane', 'NSW', 3765, 1, 3, 1654967, 'Luxury'),
#  ('Brisbane', 'WA', 1549, 5, 3, 1581911, 'Luxury'),
#  ('Brisbane', 'NSW', 3483, 5, 2, 1322401, 'Luxury'),
#  ('Melbourne', 'NSW', 923, 3, 3, 1250949, 'Luxury'),
#  ('Melbourne', 'VIC', 2057, 3, 3, 1452214, 'Luxury'),
#  ('Sydney', 'SA', 3647, 4, 1, 1311197, 'Luxury'),
#  ('Sydney', 'SA', 2157, 4, 3, 1680092, 'Luxury'),
#  ('Sydney', 'VIC', 1043, 2, 1, 1947090, 'Luxury'),
#  ('Sydney', 'WA', 2479, 2, 2, 1448082, 'Luxury'),
#  ('Melbourne', 'SA', 1958, 3, 1, 1189987, 'Luxury'),
#  ('Sydney', 'SA', 2064, 2, 2, 1631563, 'Luxury'),
#  ('Brisbane', 'QLD', 2012, 1, 1, 1028396, 'Luxury'),
#  ('Sydney', 'VIC', 3808, 1, 3, 1906163, 'Luxury'),
#  ('Melbourne', 'NSW', 2085, 3, 1, 1068359, 'Luxury'),
#  ('Melbourne', 'NSW', 1963, 2, 1, 1923231, 'Luxury'),
#  ('Melbourne', 'VIC', 1745, 4, 1, 1603930, 'Luxury'),
#  ('Brisbane', 'SA', 3041, 4, 2, 1835244, 'Luxury'),
#  ('Brisbane', 'QLD', 1316, 2, 2, 1448883, 'Luxury'),
#  ('Brisbane', 'QLD', 3367, 4, 2, 1472667, 'Luxury'),
#  ('Brisbane', 'WA', 2263, 4, 2, 1880358, 'Luxury'),
#  ('Melbourne', 'WA', 3124, 4, 3, 1782798, 'Luxury'),
#  ('Melbourne', 'QLD', 1029, 4, 1, 1342982, 'Luxury'),
#  ('Melbourne', 'QLD', 2436, 4, 2, 1115496, 'Luxury'),
#  ('Melbourne', 'NSW', 1028, 5, 1, 1129157, 'Luxury'),
#  ('Melbourne', 'VIC', 1880, 3, 1, 1227948, 'Luxury'),
#  ('Melbourne', 'WA', 1047, 4, 1, 1553121, 'Luxury'),
#  ('Sydney', 'WA', 2762, 1, 2, 1346549, 'Luxury'),
#  ('Melbourne', 'NSW', 2849, 3, 3, 1236124, 'Luxury'),
#  ('Brisbane', 'NSW', 1912, 4, 2, 1660733, 'Luxury'),
#  ('Brisbane', 'WA', 3134, 3, 3, 1902521, 'Luxury'),
#  ('Brisbane', 'NSW', 3469, 2, 2, 1832230, 'Luxury'),
#  ('Melbourne', 'SA', 3594, 2, 3, 1844482, 'Luxury'),
#  ('Melbourne', 'SA', 2094, 5, 2, 1660927, 'Luxury'),
#  ('Sydney', 'WA', 2213, 5, 3, 1222929, 'Luxury'),
#  ('Sydney', 'NSW', 1851, 2, 3, 1658630, 'Luxury'),
#  ('Brisbane', 'SA', 3740, 1, 1, 1808820, 'Luxury'),
#  ('Melbourne', 'SA', 912, 1, 2, 1019715, 'Luxury'),
#  ('Melbourne', 'QLD', 3295, 2, 3, 1766102, 'Luxury'),
#  ('Sydney', 'WA', 1447, 5, 3, 1024351, 'Luxury'),
#  ('Melbourne', 'WA', 2616, 1, 2, 1407919, 'Luxury'),
#  ('Brisbane', 'VIC', 2917, 2, 3, 1863664, 'Luxury'),
#  ('Melbourne', 'QLD', 1502, 3, 2, 1678376, 'Luxury'),
#  ('Melbourne', 'VIC', 2192, 5, 3, 1556912, 'Luxury'),
#  ('Sydney', 'NSW', 2720, 3, 3, 1953815, 'Luxury'),
#  ('Melbourne', 'SA', 1736, 2, 1, 1372610, 'Luxury'),
#  ('Melbourne', 'QLD', 1266, 2, 3, 1083414, 'Luxury'),
#  ('Melbourne', 'NSW', 3969, 2, 1, 1445898, 'Luxury'),
#  ('Brisbane', 'WA', 3991, 5, 3, 1045419, 'Luxury'),
#  ('Melbourne', 'NSW', 1648, 3, 2, 1236396, 'Luxury'),
#  ('Brisbane', 'QLD', 3085, 3, 2, 1550333, 'Luxury'),
#  ('Brisbane', 'NSW', 1318, 5, 3, 1625788, 'Luxury'),
#  ('Sydney', 'VIC', 1377, 2, 3, 1096949, 'Luxury'),
#  ('Melbourne', 'SA', 3275, 3, 2, 1191407, 'Luxury'),
#  ('Melbourne', 'VIC', 3848, 1, 3, 1805014, 'Luxury'),
#  ('Brisbane', 'SA', 2018, 3, 3, 1351917, 'Luxury'),
#  ('Brisbane', 'SA', 1282, 3, 1, 1303378, 'Luxury'),
#  ('Brisbane', 'WA', 3431, 5, 2, 1793727, 'Luxury'),
#  ('Melbourne', 'QLD', 2169, 4, 3, 1797646, 'Luxury'),
#  ('Melbourne', 'WA', 3155, 2, 2, 1001885, 'Luxury'),
#  ('Brisbane', 'WA', 1653, 3, 3, 1506885, 'Luxury'),
#  ('Sydney', 'QLD', 1477, 2, 3, 1211591, 'Luxury'),
#  ('Sydney', 'WA', 2620, 5, 3, 1989277, 'Luxury'),
#  ('Sydney', 'SA', 1987, 3, 1, 1644187, 'Luxury'),
#  ('Melbourne', 'QLD', 2465, 2, 1, 1471541, 'Luxury'),
#  ('Sydney', 'WA', 1794, 4, 1, 1323873, 'Luxury'),
#  ('Sydney', 'SA', 3964, 3, 3, 1396241, 'Luxury'),
#  ('Brisbane', 'NSW', 1244, 1, 1, 1949147, 'Luxury'),
#  ('Brisbane', 'WA', 1844, 4, 2, 1317157, 'Luxury'),
#  ('Sydney', 'QLD', 2662, 1, 2, 1753345, 'Luxury'),
#  ('Brisbane', 'QLD', 3933, 2, 2, 1148484, 'Luxury'),
#  ('Melbourne', 'VIC', 1527, 5, 1, 1650130, 'Luxury'),
#  ('Melbourne', 'WA', 3771, 2, 2, 1476600, 'Luxury'),
#  ('Brisbane', 'QLD', 2476, 2, 3, 1151778, 'Luxury'),
#  ('Brisbane', 'VIC', 2411, 4, 3, 1968460, 'Luxury'),
#  ('Melbourne', 'SA', 3906, 5, 1, 1042977, 'Luxury'),
#  ('Brisbane', 'NSW', 986, 4, 2, 1408831, 'Luxury'),
#  ('Melbourne', 'NSW', 1347, 3, 1, 1253861, 'Luxury'),
#  ('Melbourne', 'VIC', 1379, 3, 3, 1482503, 'Luxury'),
#  ('Melbourne', 'VIC', 2935, 2, 1, 1611469, 'Luxury'),
#  ('Melbourne', 'VIC', 3139, 2, 1, 1553469, 'Luxury'),
#  ('Melbourne', 'NSW', 2459, 4, 2, 1007736, 'Luxury'),
#  ('Brisbane', 'NSW', 2279, 2, 2, 1651123, 'Luxury'),
#  ('Brisbane', 'WA', 3912, 1, 1, 1482325, 'Luxury'),
#  ('Sydney', 'VIC', 2836, 5, 2, 1842822, 'Luxury'),
#  ('Melbourne', 'VIC', 2378, 3, 1, 1877489, 'Luxury'),
#  ('Melbourne', 'NSW', 1658, 2, 2, 1993093, 'Luxury'),
#  ('Sydney', 'NSW', 1409, 4, 2, 1989374, 'Luxury'),
#  ('Melbourne', 'QLD', 2806, 4, 3, 1880018, 'Luxury'),
#  ('Melbourne', 'WA', 3482, 2, 2, 1718775, 'Luxury'),
#  ('Sydney', 'VIC', 2918, 2, 3, 1405094, 'Luxury'),
#  ('Melbourne', 'QLD', 1674, 3, 3, 1929433, 'Luxury'),
#  ('Brisbane', 'WA', 3635, 3, 1, 1432990, 'Luxury'),
#  ('Melbourne', 'WA', 1889, 1, 3, 1997845, 'Luxury'),
#  ('Sydney', 'VIC', 2806, 4, 2, 1809954, 'Luxury'),
#  ('Brisbane', 'SA', 1926, 4, 1, 1291851, 'Luxury'),
#  ('Melbourne', 'WA', 1941, 5, 2, 1241938, 'Luxury'),
#  ('Melbourne', 'NSW', 2325, 3, 2, 1124307, 'Luxury'),
#  ('Sydney', 'SA', 3993, 3, 3, 1204065, 'Luxury'),
#  ('Sydney', 'NSW', 1936, 2, 3, 1013878, 'Luxury'),
#  ('Sydney', 'WA', 872, 2, 1, 1273430, 'Luxury'),
#  ('Brisbane', 'VIC', 814, 1, 1, 1454274, 'Luxury'),
#  ('Brisbane', 'NSW', 1160, 1, 3, 1554291, 'Luxury'),
#  ('Sydney', 'NSW', 1063, 1, 3, 1659353, 'Luxury'),
#  ('Melbourne', 'NSW', 1347, 4, 3, 1676537, 'Luxury'),
#  ('Melbourne', 'SA', 2526, 5, 3, 1009007, 'Luxury'),
#  ('Brisbane', 'VIC', 1914, 4, 1, 1279355, 'Luxury'),
#  ('Melbourne', 'SA', 3176, 1, 1, 1351464, 'Luxury'),
#  ('Sydney', 'NSW', 1014, 3, 3, 1347245, 'Luxury'),
#  ('Sydney', 'NSW', 2517, 2, 1, 1531131, 'Luxury'),
#  ('Brisbane', 'VIC', 3910, 4, 2, 1102066, 'Luxury'),
#  ('Melbourne', 'SA', 1099, 2, 3, 1779241, 'Luxury'),
#  ('Melbourne', 'NSW', 1169, 1, 1, 1983898, 'Luxury'),
#  ('Brisbane', 'NSW', 1431, 1, 1, 1824839, 'Luxury'),
#  ('Melbourne', 'NSW', 2278, 3, 1, 1107770, 'Luxury'),
#  ('Sydney', 'SA', 3100, 1, 2, 1047726, 'Luxury'),
#  ('Melbourne', 'QLD', 3382, 2, 2, 1786973, 'Luxury'),
#  ('Brisbane', 'VIC', 1592, 2, 1, 1376252, 'Luxury'),
#  ('Melbourne', 'VIC', 2152, 5, 1, 1176838, 'Luxury'),
#  ('Sydney', 'QLD', 3556, 5, 2, 1058024, 'Luxury'),
#  ('Brisbane', 'VIC', 2744, 2, 1, 1747620, 'Luxury'),
#  ('Sydney', 'QLD', 2638, 1, 2, 1508648, 'Luxury'),
#  ('Sydney', 'NSW', 1275, 2, 3, 1835171, 'Luxury'),
#  ('Brisbane', 'NSW', 1256, 4, 2, 1646018, 'Luxury'),
#  ('Brisbane', 'NSW', 1196, 5, 2, 1643733, 'Luxury'),
#  ('Melbourne', 'SA', 1290, 3, 2, 1446919, 'Luxury'),
#  ('Brisbane', 'NSW', 3098, 5, 2, 1177015, 'Luxury'),
#  ('Brisbane', 'SA', 2892, 1, 1, 1542800, 'Luxury'),
#  ('Brisbane', 'VIC', 1045, 2, 2, 1835156, 'Luxury'),
#  ('Sydney', 'QLD', 1680, 1, 1, 1940303, 'Luxury'),
#  ('Sydney', 'WA', 2285, 2, 2, 1587299, 'Luxury'),
#  ('Brisbane', 'WA', 2734, 3, 3, 1481941, 'Luxury'),
#  ('Melbourne', 'NSW', 1667, 4, 2, 1117565, 'Luxury'),
#  ('Melbourne', 'SA', 2039, 2, 3, 1958106, 'Luxury'),
#  ('Sydney', 'VIC', 1784, 5, 1, 1567113, 'Luxury'),
#  ('Melbourne', 'NSW', 1423, 4, 3, 1973666, 'Luxury'),
#  ('Sydney', 'NSW', 3765, 2, 2, 1398771, 'Luxury'),
#  ('Brisbane', 'SA', 1226, 5, 1, 1769952, 'Luxury'),
#  ('Sydney', 'WA', 2219, 2, 3, 1219355, 'Luxury'),
#  ('Brisbane', 'WA', 1317, 4, 3, 1895667, 'Luxury'),
#  ('Brisbane', 'WA', 2156, 3, 3, 1945385, 'Luxury'),
#  ('Sydney', 'VIC', 2066, 5, 3, 1265611, 'Luxury'),
#  ('Brisbane', 'SA', 1728, 2, 1, 1537627, 'Luxury'),
#  ('Melbourne', 'SA', 1827, 5, 3, 1254288, 'Luxury'),
#  ('Melbourne', 'WA', 2349, 4, 2, 1103646, 'Luxury'),
#  ('Melbourne', 'WA', 1342, 2, 3, 1877241, 'Luxury'),
#  ('Melbourne', 'NSW', 2857, 3, 3, 1165981, 'Luxury'),
#  ('Melbourne', 'NSW', 3411, 1, 1, 1605038, 'Luxury'),
#  ('Melbourne', 'QLD', 967, 1, 3, 1916559, 'Luxury'),
#  ('Melbourne', 'VIC', 2496, 4, 2, 1242180, 'Luxury'),
#  ('Brisbane', 'WA', 2001, 5, 2, 1155099, 'Luxury'),
#  ('Melbourne', 'VIC', 1308, 3, 3, 1089730, 'Luxury'),
#  ('Melbourne', 'QLD', 3710, 4, 2, 1576811, 'Luxury'),
#  ('Melbourne', 'QLD', 2689, 3, 1, 1542508, 'Luxury'),
#  ('Brisbane', 'QLD', 2586, 4, 1, 1805331, 'Luxury'),
#  ('Melbourne', 'VIC', 3963, 4, 1, 1117663, 'Luxury'),
#  ('Melbourne', 'QLD', 1276, 5, 3, 1110348, 'Luxury'),
#  ('Brisbane', 'WA', 2620, 5, 3, 1166046, 'Luxury'),
#  ('Sydney', 'SA', 3461, 5, 2, 1481354, 'Luxury'),
#  ('Brisbane', 'VIC', 2836, 5, 2, 1552641, 'Luxury'),
#  ('Brisbane', 'QLD', 1094, 1, 1, 1791700, 'Luxury'),
#  ('Melbourne', 'VIC', 3050, 5, 1, 1167514, 'Luxury'),
#  ('Melbourne', 'WA', 931, 3, 3, 1130251, 'Luxury'),
#  ('Brisbane', 'QLD', 2398, 3, 3, 1995549, 'Luxury'),
#  ('Brisbane', 'QLD', 3609, 4, 2, 1596156, 'Luxury'),
#  ('Brisbane', 'WA', 3953, 1, 3, 1681292, 'Luxury'),
#  ('Sydney', 'QLD', 3814, 3, 1, 1953496, 'Luxury'),
#  ('Brisbane', 'QLD', 3350, 1, 1, 1490618, 'Luxury'),
#  ('Sydney', 'WA', 826, 2, 3, 1253905, 'Luxury'),
#  ('Melbourne', 'VIC', 1335, 4, 1, 1420355, 'Luxury'),
#  ('Brisbane', 'SA', 1026, 5, 2, 1163034, 'Luxury'),
#  ('Sydney', 'WA', 2689, 5, 3, 1974055, 'Luxury'),
#  ('Brisbane', 'SA', 1148, 2, 2, 1504907, 'Luxury'),
#  ('Brisbane', 'NSW', 1596, 5, 2, 1824739, 'Luxury'),
#  ('Sydney', 'QLD', 1037, 5, 2, 1770667, 'Luxury'),
#  ('Melbourne', 'VIC', 3307, 3, 2, 1132860, 'Luxury'),
#  ('Brisbane', 'QLD', 3090, 2, 1, 1862126, 'Luxury'),
#  ('Melbourne', 'WA', 3491, 2, 3, 1343098, 'Luxury'),
#  ('Sydney', 'WA', 3748, 1, 3, 1471417, 'Luxury'),
#  ('Sydney', 'SA', 3254, 3, 2, 1576732, 'Luxury'),
#  ('Brisbane', 'SA', 3268, 3, 1, 1466753, 'Luxury'),
#  ('Sydney', 'SA', 3250, 2, 3, 1811171, 'Luxury'),
#  ('Brisbane', 'SA', 1982, 5, 2, 1193394, 'Luxury'),
#  ('Sydney', 'NSW', 2660, 3, 1, 1037064, 'Luxury'),
#  ('Brisbane', 'NSW', 1273, 5, 2, 1661551, 'Luxury'),
#  ('Brisbane', 'QLD', 1969, 1, 1, 1777403, 'Luxury'),
#  ('Sydney', 'WA', 2793, 5, 3, 1632658, 'Luxury'),
#  ('Sydney', 'NSW', 3277, 5, 1, 1869875, 'Luxury'),
#  ('Sydney', 'VIC', 3423, 3, 1, 1666785, 'Luxury'),
#  ('Brisbane', 'QLD', 3432, 4, 2, 1562555, 'Luxury'),
#  ('Brisbane', 'WA', 3123, 3, 3, 1920004, 'Luxury'),
#  ('Sydney', 'VIC', 3587, 3, 3, 1411961, 'Luxury'),
#  ('Melbourne', 'WA', 1691, 1, 1, 1324829, 'Luxury'),
#  ('Melbourne', 'VIC', 1929, 2, 2, 1242331, 'Luxury'),
#  ('Melbourne', 'VIC', 1668, 5, 2, 1869075, 'Luxury'),
#  ('Brisbane', 'WA', 2227, 5, 1, 1906778, 'Luxury'),
#  ('Brisbane', 'WA', 3969, 5, 2, 1732589, 'Luxury'),
#  ('Melbourne', 'SA', 2726, 4, 1, 1174411, 'Luxury'),
#  ('Brisbane', 'SA', 2162, 4, 3, 1204285, 'Luxury'),
#  ('Sydney', 'NSW', 1154, 3, 1, 1956892, 'Luxury'),
#  ('Brisbane', 'QLD', 1367, 2, 2, 1523234, 'Luxury'),
#  ('Sydney', 'NSW', 1032, 5, 2, 1127508, 'Luxury'),
#  ('Brisbane', 'SA', 1325, 4, 2, 1047898, 'Luxury'),
#  ('Sydney', 'NSW', 3491, 1, 2, 1869816, 'Luxury'),
#  ('Melbourne', 'WA', 3721, 2, 2, 1313305, 'Luxury'),
#  ('Brisbane', 'WA', 2754, 1, 3, 1982133, 'Luxury'),
#  ('Brisbane', 'VIC', 3667, 4, 1, 1031022, 'Luxury'),
#  ('Brisbane', 'NSW', 3906, 1, 2, 1589021, 'Luxury'),
#  ('Brisbane', 'NSW', 2571, 5, 1, 1169732, 'Luxury'),
#  ('Melbourne', 'SA', 1617, 1, 2, 1017232, 'Luxury'),
#  ('Sydney', 'WA', 3605, 1, 2, 1162112, 'Luxury'),
#  ('Brisbane', 'QLD', 2550, 3, 3, 1834930, 'Luxury'),
#  ('Sydney', 'VIC', 3926, 4, 3, 1863787, 'Luxury'),
#  ('Brisbane', 'VIC', 3161, 5, 1, 1133455, 'Luxury'),
#  ('Melbourne', 'QLD', 3354, 3, 3, 1252151, 'Luxury'),
#  ('Sydney', 'QLD', 2380, 4, 2, 1336000, 'Luxury'),
#  ('Melbourne', 'WA', 1577, 5, 2, 1526894, 'Luxury'),
#  ('Sydney', 'VIC', 1938, 3, 2, 1603876, 'Luxury'),
#  ('Sydney', 'QLD', 2558, 4, 3, 1345414, 'Luxury'),
#  ('Brisbane', 'NSW', 2184, 1, 3, 1573961, 'Luxury'),
#  ('Brisbane', 'VIC', 2915, 4, 3, 1646651, 'Luxury'),
#  ('Sydney', 'NSW', 2519, 2, 3, 1304073, 'Luxury'),
#  ('Melbourne', 'NSW', 1521, 2, 1, 1426959, 'Luxury'),
#  ('Sydney', 'QLD', 1884, 1, 1, 1126929, 'Luxury'),
#  ('Brisbane', 'WA', 2142, 1, 3, 1337480, 'Luxury'),
#  ('Sydney', 'WA', 1524, 5, 2, 1453793, 'Luxury'),
#  ('Melbourne', 'QLD', 2874, 2, 1, 1050862, 'Luxury'),
#  ('Brisbane', 'QLD', 2251, 3, 2, 1678536, 'Luxury'),
#  ('Brisbane', 'VIC', 3374, 4, 1, 1611184, 'Luxury'),
#  ('Melbourne', 'SA', 1655, 1, 1, 1304190, 'Luxury'),
#  ('Brisbane', 'SA', 2252, 2, 3, 1019402, 'Luxury'),
#  ('Sydney', 'QLD', 3056, 2, 1, 1696699, 'Luxury'),
#  ('Melbourne', 'VIC', 821, 4, 1, 1715333, 'Luxury'),
#  ('Sydney', 'VIC', 812, 5, 2, 1309330, 'Luxury'),
#  ('Brisbane', 'WA', 2565, 2, 1, 1797361, 'Luxury'),
#  ('Brisbane', 'QLD', 1677, 3, 1, 1255271, 'Luxury'),
#  ('Sydney', 'VIC', 3706, 1, 3, 1831995, 'Luxury'),
#  ('Sydney', 'WA', 3009, 4, 1, 1746965, 'Luxury'),
#  ('Melbourne', 'WA', 3578, 5, 3, 1132609, 'Luxury'),
#  ('Melbourne', 'QLD', 3670, 3, 1, 1114246, 'Luxury'),
#  ('Melbourne', 'WA', 3856, 1, 3, 1263007, 'Luxury'),
#  ('Melbourne', 'QLD', 920, 2, 2, 1620935, 'Luxury'),
#  ('Melbourne', 'NSW', 2634, 2, 1, 1497482, 'Luxury'),
#  ('Brisbane', 'WA', 3700, 3, 3, 1891613, 'Luxury'),
#  ('Sydney', 'QLD', 3494, 1, 1, 1777242, 'Luxury'),
#  ('Brisbane', 'VIC', 1841, 3, 2, 1058129, 'Luxury'),
#  ('Melbourne', 'SA', 2840, 5, 1, 1644978, 'Luxury'),
#  ('Brisbane', 'VIC', 2581, 3, 2, 1152728, 'Luxury'),
#  ('Melbourne', 'SA', 2923, 2, 1, 1028983, 'Luxury'),
#  ('Brisbane', 'VIC', 3230, 2, 3, 1575231, 'Luxury'),
#  ('Melbourne', 'VIC', 2652, 2, 3, 1816234, 'Luxury'),
#  ('Sydney', 'QLD', 3556, 3, 1, 1100012, 'Luxury'),
#  ('Sydney', 'QLD', 3679, 1, 1, 1629255, 'Luxury'),
#  ('Melbourne', 'SA', 2851, 1, 2, 1140146, 'Luxury'),
#  ('Melbourne', 'VIC', 3269, 4, 1, 1715106, 'Luxury'),
#  ('Sydney', 'VIC', 1204, 3, 3, 1015456, 'Luxury'),
#  ('Melbourne', 'WA', 1924, 3, 2, 1020087, 'Luxury'),
#  ('Brisbane', 'SA', 3562, 3, 3, 1673927, 'Luxury'),
#  ('Melbourne', 'VIC', 1386, 3, 1, 1851908, 'Luxury'),
#  ('Brisbane', 'QLD', 845, 1, 3, 1600136, 'Luxury'),
#  ('Melbourne', 'QLD', 2772, 5, 2, 1569639, 'Luxury'),
#  ('Melbourne', 'VIC', 3172, 1, 3, 1268498, 'Luxury'),
#  ('Melbourne', 'VIC', 3614, 1, 3, 1436358, 'Luxury'),
#  ('Brisbane', 'NSW', 1229, 1, 3, 1892475, 'Luxury'),
#  ('Melbourne', 'NSW', 870, 3, 2, 1461414, 'Luxury'),
#  ('Melbourne', 'VIC', 1642, 5, 1, 1090859, 'Luxury'),
#  ('Brisbane', 'VIC', 2856, 4, 1, 1700524, 'Luxury'),
#  ('Sydney', 'SA', 1736, 1, 1, 1899372, 'Luxury'),
#  ('Melbourne', 'SA', 3326, 1, 1, 1104429, 'Luxury'),
#  ('Sydney', 'QLD', 2586, 3, 2, 1533444, 'Luxury'),
#  ('Brisbane', 'SA', 3369, 2, 1, 1713133, 'Luxury'),
#  ('Melbourne', 'SA', 3114, 4, 3, 1370684, 'Luxury'),
#  ('Melbourne', 'QLD', 3831, 2, 1, 1159676, 'Luxury'),
#  ('Brisbane', 'VIC', 3438, 2, 1, 1998273, 'Luxury'),
#  ('Melbourne', 'QLD', 2586, 5, 3, 1733804, 'Luxury'),
#  ('Brisbane', 'WA', 3482, 1, 3, 1615979, 'Luxury'),
#  ('Melbourne', 'VIC', 1226, 2, 1, 1745783, 'Luxury'),
#  ('Brisbane', 'SA', 824, 1, 2, 1245182, 'Luxury'),
#  ('Brisbane', 'WA', 3102, 1, 1, 1930048, 'Luxury'),
#  ('Melbourne', 'VIC', 2151, 5, 2, 1633129, 'Luxury'),
#  ('Melbourne', 'NSW', 2179, 3, 1, 1141966, 'Luxury'),
#  ('Sydney', 'VIC', 1863, 3, 3, 1052020, 'Luxury'),
#  ('Sydney', 'VIC', 2832, 4, 2, 1501079, 'Luxury'),
#  ('Sydney', 'SA', 2812, 4, 2, 1927214, 'Luxury'),
#  ('Brisbane', 'QLD', 2113, 5, 1, 1634543, 'Luxury'),
#  ('Brisbane', 'WA', 3978, 2, 1, 1806023, 'Luxury'),
#  ('Brisbane', 'SA', 1747, 5, 1, 1960527, 'Luxury'),
#  ('Melbourne', 'VIC', 2594, 2, 3, 1537777, 'Luxury'),
#  ('Brisbane', 'WA', 3655, 2, 3, 1115860, 'Luxury'),
#  ('Sydney', 'QLD', 2270, 3, 2, 1603834, 'Luxury'),
#  ('Brisbane', 'WA', 1318, 2, 1, 1680623, 'Luxury'),
#  ('Melbourne', 'WA', 2544, 3, 1, 1761156, 'Luxury'),
#  ('Sydney', 'NSW', 966, 2, 2, 1652772, 'Luxury'),
#  ('Melbourne', 'QLD', 2557, 3, 1, 1965988, 'Luxury'),
#  ('Sydney', 'VIC', 2682, 1, 1, 1226181, 'Luxury'),
#  ('Sydney', 'NSW', 3034, 3, 3, 1254048, 'Luxury'),
#  ('Melbourne', 'WA', 3497, 4, 3, 1560555, 'Luxury'),
#  ('Brisbane', 'QLD', 1220, 4, 2, 1959848, 'Luxury'),
#  ('Melbourne', 'SA', 3986, 2, 1, 1936224, 'Luxury'),
#  ('Brisbane', 'VIC', 2427, 5, 2, 1870838, 'Luxury'),
#  ('Sydney', 'NSW', 3362, 4, 3, 1394844, 'Luxury'),
#  ('Melbourne', 'NSW', 3740, 4, 2, 1505536, 'Luxury'),
#  ('Brisbane', 'WA', 1854, 4, 3, 1214785, 'Luxury'),
#  ('Melbourne', 'WA', 3266, 3, 1, 1861641, 'Luxury'),
#  ('Brisbane', 'WA', 1631, 1, 2, 1414325, 'Luxury'),
#  ('Melbourne', 'NSW', 3234, 4, 3, 1342454, 'Luxury'),
#  ('Brisbane', 'VIC', 2336, 5, 1, 1151163, 'Luxury'),
#  ('Sydney', 'QLD', 2751, 2, 3, 1167721, 'Luxury'),
#  ('Melbourne', 'WA', 869, 4, 2, 1262561, 'Luxury'),
#  ('Brisbane', 'NSW', 3965, 3, 3, 1071384, 'Luxury'),
#  ('Melbourne', 'NSW', 3248, 3, 2, 1379541, 'Luxury'),
#  ('Sydney', 'NSW', 868, 1, 1, 1392586, 'Luxury'),
#  ('Brisbane', 'VIC', 1479, 3, 2, 1205800, 'Luxury'),
#  ('Melbourne', 'WA', 1105, 3, 3, 1951554, 'Luxury'),
#  ('Melbourne', 'NSW', 978, 1, 1, 1292806, 'Luxury'),
#  ('Brisbane', 'NSW', 2028, 2, 1, 1986522, 'Luxury'),
#  ('Melbourne', 'VIC', 3592, 4, 1, 1398733, 'Luxury'),
#  ('Melbourne', 'QLD', 2265, 4, 1, 1219072, 'Luxury'),
#  ('Sydney', 'SA', 2658, 4, 3, 1135971, 'Luxury'),
#  ('Brisbane', 'NSW', 2800, 5, 1, 1248981, 'Luxury'),
#  ('Brisbane', 'NSW', 1008, 5, 2, 1895077, 'Luxury'),
#  ('Melbourne', 'SA', 907, 5, 2, 1497398, 'Luxury'),
#  ('Sydney', 'VIC', 3467, 1, 2, 1465586, 'Luxury'),
#  ('Melbourne', 'WA', 3346, 5, 2, 1326427, 'Luxury'),
#  ('Melbourne', 'NSW', 3269, 1, 3, 1929540, 'Luxury'),
#  ('Melbourne', 'QLD', 3690, 3, 2, 1871299, 'Luxury'),
#  ('Brisbane', 'NSW', 3384, 4, 1, 1569835, 'Luxury'),
#  ('Sydney', 'SA', 3711, 5, 3, 1069634, 'Luxury'),
#  ('Sydney', 'WA', 2890, 1, 2, 1902154, 'Luxury'),
#  ('Sydney', 'VIC', 2448, 5, 3, 1336086, 'Luxury'),
#  ('Melbourne', 'SA', 2538, 1, 3, 1002044, 'Luxury'),
#  ('Melbourne', 'SA', 3933, 1, 3, 1566780, 'Luxury'),
#  ('Melbourne', 'WA', 2267, 5, 3, 1205779, 'Luxury'),
#  ('Melbourne', 'NSW', 2373, 1, 2, 1824543, 'Luxury'),
#  ('Sydney', 'NSW', 2306, 5, 1, 1718416, 'Luxury'),
#  ('Melbourne', 'WA', 2550, 3, 2, 1364613, 'Luxury'),
#  ('Sydney', 'WA', 2764, 1, 1, 1518231, 'Luxury'),
#  ('Brisbane', 'QLD', 3583, 4, 1, 1710484, 'Luxury'),
#  ('Melbourne', 'VIC', 3475, 2, 1, 1142049, 'Luxury'),
#  ('Melbourne', 'NSW', 2007, 5, 3, 1384849, 'Luxury'),
#  ('Sydney', 'WA', 2930, 1, 1, 1400439, 'Luxury'),
#  ('Melbourne', 'QLD', 1064, 3, 3, 1573355, 'Luxury'),
#  ('Brisbane', 'SA', 2874, 2, 2, 1064264, 'Luxury'),
#  ('Sydney', 'WA', 816, 5, 1, 1112072, 'Luxury'),
#  ('Brisbane', 'VIC', 2406, 1, 1, 1884487, 'Luxury'),
#  ('Sydney', 'WA', 3086, 1, 1, 1492731, 'Luxury'),
#  ('Brisbane', 'NSW', 1315, 1, 2, 1471631, 'Luxury'),
#  ('Melbourne', 'NSW', 1734, 4, 1, 1494970, 'Luxury'),
#  ('Brisbane', 'NSW', 3582, 1, 1, 1894407, 'Luxury'),
#  ('Sydney', 'NSW', 1582, 2, 2, 1782259, 'Luxury'),
#  ('Sydney', 'NSW', 2844, 2, 2, 1432513, 'Luxury'),
#  ('Brisbane', 'VIC', 2995, 3, 3, 1957850, 'Luxury'),
#  ('Sydney', 'SA', 2895, 1, 2, 1878602, 'Luxury'),
#  ('Melbourne', 'WA', 1095, 5, 1, 1081637, 'Luxury'),
#  ('Sydney', 'QLD', 1289, 4, 3, 1958608, 'Luxury'),
#  ('Melbourne', 'QLD', 1619, 1, 1, 1539728, 'Luxury'),
#  ('Melbourne', 'VIC', 1121, 2, 1, 1080311, 'Luxury'),
#  ('Sydney', 'WA', 1166, 2, 2, 1358028, 'Luxury'),
#  ('Melbourne', 'VIC', 3675, 2, 2, 1369019, 'Luxury'),
#  ('Melbourne', 'WA', 1479, 2, 1, 1496990, 'Luxury'),
#  ('Melbourne', 'WA', 2656, 5, 1, 1784890, 'Luxury'),
#  ('Melbourne', 'SA', 3019, 4, 1, 1817987, 'Luxury'),
#  ('Sydney', 'SA', 2507, 5, 3, 1912487, 'Luxury'),
#  ('Brisbane', 'QLD', 1981, 4, 1, 1526929, 'Luxury'),
#  ('Brisbane', 'WA', 1050, 3, 2, 1555854, 'Luxury'),
#  ('Sydney', 'WA', 3156, 4, 2, 1780667, 'Luxury'),
#  ('Sydney', 'QLD', 2761, 4, 1, 1386920, 'Luxury'),
#  ('Melbourne', 'VIC', 1017, 2, 2, 1925487, 'Luxury'),
#  ('Melbourne', 'VIC', 2186, 4, 2, 1141058, 'Luxury'),
#  ('Brisbane', 'NSW', 2059, 3, 3, 1522740, 'Luxury'),
#  ('Sydney', 'SA', 1038, 2, 1, 1303975, 'Luxury'),
#  ('Sydney', 'SA', 3433, 3, 2, 1202344, 'Luxury'),
#  ('Sydney', 'WA', 2397, 5, 1, 1481318, 'Luxury'),
#  ('Melbourne', 'QLD', 1350, 4, 2, 1010555, 'Luxury'),
#  ('Brisbane', 'NSW', 869, 5, 3, 1964716, 'Luxury'),
#  ('Sydney', 'QLD', 2937, 2, 2, 1974749, 'Luxury'),
#  ('Sydney', 'WA', 3798, 5, 2, 1498193, 'Luxury'),
#  ('Melbourne', 'WA', 3348, 5, 1, 1943150, 'Luxury'),
#  ('Melbourne', 'VIC', 1476, 5, 1, 1506464, 'Luxury'),
#  ('Brisbane', 'WA', 1340, 3, 3, 1222319, 'Luxury'),
#  ('Sydney', 'SA', 2636, 4, 2, 1002025, 'Luxury'),
#  ('Sydney', 'SA', 1870, 3, 2, 1519112, 'Luxury'),
#  ('Melbourne', 'QLD', 914, 4, 1, 1012113, 'Luxury'),
#  ('Sydney', 'NSW', 2946, 2, 2, 1876749, 'Luxury'),
#  ('Brisbane', 'WA', 2773, 5, 1, 1981856, 'Luxury'),
#  ('Melbourne', 'NSW', 997, 4, 1, 1999701, 'Luxury'),
#  ('Brisbane', 'VIC', 3432, 4, 2, 1165814, 'Luxury'),
#  ('Brisbane', 'QLD', 2840, 4, 3, 1462410, 'Luxury'),
#  ('Melbourne', 'NSW', 1561, 5, 2, 1827793, 'Luxury'),
#  ('Brisbane', 'SA', 1977, 1, 1, 1007631, 'Luxury'),
#  ('Sydney', 'QLD', 1480, 3, 1, 1526825, 'Luxury'),
#  ('Melbourne', 'NSW', 1948, 5, 1, 1349120, 'Luxury'),
#  ('Sydney', 'SA', 1971, 2, 2, 1660382, 'Luxury'),
#  ('Sydney', 'NSW', 1525, 1, 1, 1291931, 'Luxury'),
#  ('Sydney', 'SA', 3701, 4, 3, 1412399, 'Luxury'),
#  ('Brisbane', 'QLD', 816, 1, 2, 1077864, 'Luxury'),
#  ('Melbourne', 'NSW', 3598, 2, 1, 1035333, 'Luxury'),
#  ('Melbourne', 'QLD', 3747, 4, 1, 1219256, 'Luxury'),
#  ('Sydney', 'NSW', 3598, 4, 1, 1442806, 'Luxury'),
#  ('Sydney', 'SA', 3156, 5, 1, 1868984, 'Luxury'),
#  ('Melbourne', 'VIC', 2187, 2, 2, 1440782, 'Luxury'),
#  ('Melbourne', 'WA', 1213, 2, 3, 1816892, 'Luxury'),
#  ('Brisbane', 'VIC', 895, 4, 3, 1636171, 'Luxury'),
#  ('Brisbane', 'NSW', 1038, 4, 3, 1552406, 'Luxury'),
#  ('Brisbane', 'QLD', 3759, 3, 1, 1743080, 'Luxury'),
#  ('Sydney', 'QLD', 1644, 5, 1, 1520441, 'Luxury'),
#  ('Melbourne', 'NSW', 3186, 1, 2, 1861049, 'Luxury'),
#  ('Brisbane', 'WA', 2721, 1, 2, 1291281, 'Luxury'),
#  ('Sydney', 'SA', 1115, 2, 1, 1756733, 'Luxury'),
#  ('Brisbane', 'SA', 985, 3, 1, 1449640, 'Luxury'),
#  ('Brisbane', 'QLD', 3195, 1, 1, 1708335, 'Luxury'),
#  ('Melbourne', 'NSW', 869, 5, 1, 1172074, 'Luxury'),
#  ('Sydney', 'WA', 1750, 1, 1, 1705667, 'Luxury'),
#  ('Sydney', 'WA', 1506, 1, 1, 1750103, 'Luxury'),
#  ('Brisbane', 'VIC', 1006, 4, 2, 1487801, 'Luxury'),
#  ('Brisbane', 'NSW', 896, 5, 2, 1429005, 'Luxury'),
#  ('Brisbane', 'SA', 1441, 5, 1, 1188678, 'Luxury'),
#  ('Melbourne', 'WA', 1519, 5, 3, 1016383, 'Luxury'),
#  ('Melbourne', 'WA', 3372, 4, 2, 1285923, 'Luxury'),
#  ('Brisbane', 'WA', 2813, 4, 3, 1256479, 'Luxury'),
#  ('Melbourne', 'QLD', 3800, 3, 1, 1582669, 'Luxury'),
#  ('Melbourne', 'WA', 1397, 2, 2, 1282886, 'Luxury'),
#  ('Brisbane', 'VIC', 3347, 4, 1, 1885945, 'Luxury'),
#  ('Melbourne', 'VIC', 3093, 1, 2, 1605595, 'Luxury'),
#  ('Sydney', 'QLD', 3360, 5, 2, 1422756, 'Luxury'),
#  ('Melbourne', 'SA', 3409, 5, 1, 1835714, 'Luxury'),
#  ('Sydney', 'QLD', 1765, 3, 3, 1575947, 'Luxury'),
#  ('Sydney', 'QLD', 3509, 2, 3, 1679801, 'Luxury'),
#  ('Brisbane', 'WA', 1421, 4, 2, 1185928, 'Luxury'),
#  ('Sydney', 'VIC', 883, 4, 3, 1538813, 'Luxury'),
#  ('Brisbane', 'SA', 1342, 2, 1, 1872882, 'Luxury'),
#  ('Melbourne', 'SA', 2653, 3, 2, 1108515, 'Luxury'),
#  ('Sydney', 'WA', 2631, 3, 1, 1495767, 'Luxury'),
#  ('Sydney', 'VIC', 2876, 4, 2, 1133668, 'Luxury'),
#  ('Brisbane', 'SA', 1171, 1, 2, 1856354, 'Luxury'),
#  ('Sydney', 'QLD', 3805, 1, 3, 1547608, 'Luxury'),
#  ('Brisbane', 'SA', 1255, 5, 3, 1739233, 'Luxury'),
#  ('Melbourne', 'SA', 2247, 1, 2, 1061672, 'Luxury'),
#  ('Sydney', 'NSW', 2526, 3, 3, 1721251, 'Luxury'),
#  ('Brisbane', 'WA', 2511, 4, 2, 1600964, 'Luxury'),
#  ('Brisbane', 'NSW', 2960, 4, 1, 1639348, 'Luxury'),
#  ('Melbourne', 'VIC', 1277, 5, 1, 1803441, 'Luxury'),
#  ('Sydney', 'QLD', 1900, 2, 2, 1211162, 'Luxury'),
#  ('Melbourne', 'SA', 3250, 2, 2, 1701412, 'Luxury'),
#  ('Brisbane', 'VIC', 3742, 1, 1, 1287191, 'Luxury'),
#  ('Melbourne', 'SA', 3111, 5, 1, 1292639, 'Luxury'),
#  ('Sydney', 'VIC', 2344, 5, 3, 1387826, 'Luxury'),
#  ('Brisbane', 'QLD', 1010, 5, 1, 1985556, 'Luxury'),
#  ('Sydney', 'WA', 2881, 2, 2, 1018746, 'Luxury'),
#  ('Melbourne', 'QLD', 3609, 2, 3, 1523450, 'Luxury'),
#  ('Melbourne', 'WA', 2404, 2, 3, 1474013, 'Luxury'),
#  ('Brisbane', 'NSW', 2594, 3, 3, 1963397, 'Luxury'),
#  ('Melbourne', 'WA', 1585, 1, 2, 1848818, 'Luxury'),
#  ('Melbourne', 'WA', 2083, 5, 1, 1288108, 'Luxury'),
#  ('Brisbane', 'QLD', 1341, 1, 2, 1253069, 'Luxury'),
#  ('Sydney', 'VIC', 3354, 4, 1, 1887322, 'Luxury'),
#  ('Brisbane', 'WA', 1124, 3, 2, 1132638, 'Luxury'),
#  ('Sydney', 'VIC', 2243, 1, 2, 1184958, 'Luxury'),
#  ('Sydney', 'VIC', 3674, 2, 1, 1137411, 'Luxury'),
#  ('Sydney', 'WA', 3508, 3, 3, 1860173, 'Luxury'),
#  ('Brisbane', 'QLD', 3017, 5, 3, 1169961, 'Luxury'),
#  ('Brisbane', 'NSW', 2817, 1, 3, 1195821, 'Luxury'),
#  ('Sydney', 'WA', 831, 1, 2, 1229360, 'Luxury'),
#  ('Melbourne', 'VIC', 3590, 3, 3, 1695853, 'Luxury'),
#  ('Brisbane', 'VIC', 3658, 5, 2, 1680984, 'Luxury'),
#  ('Sydney', 'VIC', 1246, 2, 1, 1881085, 'Luxury'),
#  ('Sydney', 'WA', 1475, 4, 3, 1121813, 'Luxury'),
#  ('Brisbane', 'NSW', 3445, 5, 3, 1655921, 'Luxury'),
#  ('Melbourne', 'WA', 2568, 1, 1, 1853086, 'Luxury'),
#  ('Sydney', 'NSW', 1734, 3, 1, 1835942, 'Luxury'),
#  ('Sydney', 'VIC', 3200, 3, 1, 1755406, 'Luxury'),
#  ('Melbourne', 'WA', 1399, 3, 1, 1090687, 'Luxury'),
#  ('Brisbane', 'NSW', 1946, 5, 2, 1996306, 'Luxury'),
#  ('Brisbane', 'VIC', 990, 2, 2, 1743269, 'Luxury'),
#  ('Brisbane', 'VIC', 1419, 1, 2, 1114838, 'Luxury'),
#  ('Sydney', 'QLD', 3060, 4, 1, 1586052, 'Luxury'),
#  ('Brisbane', 'VIC', 3444, 1, 1, 1958572, 'Luxury'),
#  ('Sydney', 'WA', 1932, 1, 2, 1744222, 'Luxury'),
#  ('Sydney', 'QLD', 2067, 2, 2, 1376793, 'Luxury'),
#  ('Melbourne', 'QLD', 3780, 3, 3, 1068581, 'Luxury'),
#  ('Brisbane', 'SA', 2791, 3, 3, 1106578, 'Luxury'),
#  ('Sydney', 'WA', 874, 4, 3, 1991781, 'Luxury'),
#  ('Melbourne', 'WA', 1661, 5, 2, 1432895, 'Luxury'),
#  ('Melbourne', 'VIC', 1697, 4, 1, 1962710, 'Luxury'),
#  ('Brisbane', 'SA', 3442, 2, 3, 1445282, 'Luxury'),
#  ('Melbourne', 'VIC', 2826, 4, 2, 1887433, 'Luxury'),
#  ('Melbourne', 'WA', 1586, 2, 1, 1344403, 'Luxury'),
#  ('Melbourne', 'VIC', 1442, 4, 2, 1642782, 'Luxury'),
#  ('Brisbane', 'SA', 3838, 1, 2, 1182364, 'Luxury'),
#  ('Brisbane', 'WA', 2364, 5, 2, 1334193, 'Luxury'),
#  ('Melbourne', 'VIC', 3651, 2, 2, 1924847, 'Luxury'),
#  ('Melbourne', 'QLD', 863, 4, 2, 1509372, 'Luxury'),
#  ('Melbourne', 'QLD', 3097, 3, 3, 1474612, 'Luxury'),
#  ('Brisbane', 'SA', 1705, 5, 1, 1123367, 'Luxury'),
#  ('Melbourne', 'SA', 1628, 2, 3, 1022909, 'Luxury'),
#  ('Brisbane', 'WA', 885, 5, 3, 1348764, 'Luxury'),
#  ('Melbourne', 'WA', 1643, 4, 2, 1688033, 'Luxury'),
#  ('Sydney', 'VIC', 1379, 5, 3, 1912335, 'Luxury'),
#  ('Brisbane', 'NSW', 1564, 4, 3, 1171412, 'Luxury'),
#  ('Brisbane', 'SA', 2559, 3, 2, 1450737, 'Luxury'),
#  ('Sydney', 'QLD', 3473, 5, 2, 1906408, 'Luxury'),
#  ('Brisbane', 'QLD', 2058, 4, 1, 1364678, 'Luxury'),
#  ('Melbourne', 'QLD', 2189, 4, 3, 1925149, 'Luxury'),
#  ('Melbourne', 'NSW', 2728, 2, 3, 1287174, 'Luxury'),
#  ('Sydney', 'VIC', 937, 3, 3, 1553528, 'Luxury'),
#  ('Melbourne', 'WA', 2370, 2, 2, 1281608, 'Luxury'),
#  ('Brisbane', 'SA', 2731, 2, 3, 1315715, 'Luxury'),
#  ('Melbourne', 'SA', 1748, 3, 2, 1145249, 'Luxury'),
#  ('Melbourne', 'VIC', 1954, 3, 2, 1061907, 'Luxury'),
#  ('Melbourne', 'WA', 1586, 1, 3, 1336005, 'Luxury'),
#  ('Brisbane', 'QLD', 1701, 3, 2, 1909676, 'Luxury'),
#  ('Brisbane', 'WA', 2326, 5, 3, 1109121, 'Luxury'),
#  ('Melbourne', 'WA', 1974, 3, 1, 1621735, 'Luxury'),
#  ('Melbourne', 'NSW', 1949, 1, 2, 1636666, 'Luxury'),
#  ('Melbourne', 'SA', 945, 3, 1, 1148268, 'Luxury'),
#  ('Brisbane', 'NSW', 3912, 4, 2, 1900234, 'Luxury'),
#  ('Melbourne', 'WA', 2275, 3, 2, 1180051, 'Luxury'),
#  ('Sydney', 'SA', 1920, 1, 2, 1976183, 'Luxury'),
#  ('Sydney', 'QLD', 2812, 4, 2, 1006203, 'Luxury'),
#  ('Sydney', 'VIC', 3841, 3, 1, 1423952, 'Luxury'),
#  ('Melbourne', 'VIC', 1366, 3, 2, 1215367, 'Luxury'),
#  ('Melbourne', 'VIC', 1140, 4, 3, 1090860, 'Luxury'),
#  ('Sydney', 'WA', 3703, 1, 2, 1950367, 'Luxury'),
#  ('Melbourne', 'VIC', 3690, 4, 3, 1788532, 'Luxury'),
#  ('Melbourne', 'SA', 992, 1, 2, 1900075, 'Luxury'),
#  ('Sydney', 'WA', 2752, 5, 1, 1146913, 'Luxury'),
#  ('Brisbane', 'SA', 1791, 2, 1, 1779487, 'Luxury'),
#  ('Sydney', 'QLD', 1309, 3, 2, 1787073, 'Luxury'),
#  ('Brisbane', 'VIC', 2631, 2, 1, 1492159, 'Luxury'),
#  ('Sydney', 'SA', 3800, 1, 3, 1769975, 'Luxury'),
#  ('Brisbane', 'VIC', 875, 2, 3, 1580740, 'Luxury'),
#  ('Sydney', 'NSW', 2366, 1, 2, 1599635, 'Luxury'),
#  ('Melbourne', 'NSW', 2502, 5, 2, 1882890, 'Luxury'),
#  ('Brisbane', 'SA', 3654, 1, 3, 1731605, 'Luxury'),
#  ('Sydney', 'NSW', 941, 4, 3, 1571343, 'Luxury'),
#  ('Melbourne', 'SA', 2024, 4, 2, 1425070, 'Luxury'),
#  ('Sydney', 'SA', 3484, 5, 3, 1963497, 'Luxury'),
#  ('Brisbane', 'WA', 1539, 5, 1, 1935732, 'Luxury'),
#  ('Sydney', 'SA', 2270, 5, 2, 1068333, 'Luxury'),
#  ('Brisbane', 'SA', 3771, 1, 3, 1780767, 'Luxury'),
#  ('Sydney', 'VIC', 3547, 1, 1, 1035614, 'Luxury'),
#  ('Melbourne', 'QLD', 2273, 3, 3, 1806924, 'Luxury'),
#  ('Sydney', 'SA', 1191, 2, 3, 1087856, 'Luxury'),
#  ('Melbourne', 'SA', 2829, 5, 1, 1178705, 'Luxury'),
#  ('Melbourne', 'NSW', 3173, 2, 3, 1751143, 'Luxury'),
#  ('Melbourne', 'SA', 3267, 4, 1, 1508830, 'Luxury'),
#  ('Melbourne', 'WA', 825, 2, 1, 1796720, 'Luxury'),
#  ('Brisbane', 'NSW', 3012, 5, 2, 1550452, 'Luxury'),
#  ('Sydney', 'WA', 1196, 3, 2, 1686537, 'Luxury'),
#  ('Melbourne', 'SA', 1599, 3, 2, 1068300, 'Luxury'),
#  ('Brisbane', 'VIC', 3410, 1, 2, 1783964, 'Luxury'),
#  ('Brisbane', 'VIC', 2485, 3, 3, 1790587, 'Luxury'),
#  ('Sydney', 'SA', 3253, 3, 3, 1636914, 'Luxury'),
#  ('Sydney', 'VIC', 3128, 2, 1, 1548563, 'Luxury'),
#  ('Melbourne', 'WA', 2997, 4, 1, 1078413, 'Luxury'),
#  ('Melbourne', 'VIC', 1224, 1, 1, 1968940, 'Luxury'),
#  ('Brisbane', 'SA', 1881, 4, 3, 1232089, 'Luxury'),
#  ('Brisbane', 'QLD', 3486, 3, 1, 1488524, 'Luxury'),
#  ('Melbourne', 'NSW', 2672, 4, 3, 1446231, 'Luxury'),
#  ('Melbourne', 'QLD', 1046, 1, 1, 1530925, 'Luxury'),
#  ('Sydney', 'WA', 2932, 2, 1, 1994550, 'Luxury'),
#  ('Melbourne', 'VIC', 3672, 4, 2, 1354393, 'Luxury'),
#  ('Sydney', 'VIC', 1410, 3, 1, 1655235, 'Luxury'),
#  ('Melbourne', 'VIC', 3898, 1, 1, 1319813, 'Luxury'),
#  ('Sydney', 'QLD', 1308, 2, 3, 1907649, 'Luxury'),
#  ('Brisbane', 'QLD', 1559, 3, 2, 1191364, 'Luxury'),
#  ('Sydney', 'QLD', 1982, 1, 1, 1336501, 'Luxury'),
#  ('Melbourne', 'SA', 963, 3, 3, 1386730, 'Luxury'),
#  ('Brisbane', 'QLD', 2621, 2, 3, 1405332, 'Luxury'),
#  ('Brisbane', 'SA', 2667, 5, 2, 1985832, 'Luxury'),
#  ('Sydney', 'WA', 2050, 4, 3, 1733160, 'Luxury'),
#  ('Sydney', 'VIC', 2842, 4, 1, 1533386, 'Luxury'),
#  ('Brisbane', 'SA', 3847, 3, 1, 1948266, 'Luxury'),
#  ('Brisbane', 'VIC', 1460, 2, 2, 1302609, 'Luxury'),
#  ('Sydney', 'NSW', 3363, 4, 2, 1585350, 'Luxury'),
#  ('Melbourne', 'NSW', 1181, 2, 3, 1845527, 'Luxury'),
#  ('Melbourne', 'SA', 1202, 3, 1, 1245523, 'Luxury'),
#  ('Melbourne', 'QLD', 3631, 2, 1, 1889693, 'Luxury'),
#  ('Melbourne', 'SA', 3328, 4, 2, 1633097, 'Luxury'),
#  ('Sydney', 'SA', 2976, 4, 2, 1313452, 'Luxury'),
#  ('Brisbane', 'NSW', 1608, 5, 1, 1646480, 'Luxury'),
#  ('Melbourne', 'WA', 3743, 3, 1, 1936819, 'Luxury'),
#  ('Melbourne', 'SA', 2296, 3, 2, 1913387, 'Luxury'),
#  ('Sydney', 'QLD', 3464, 2, 1, 1095527, 'Luxury'),
#  ('Brisbane', 'WA', 2720, 3, 3, 1322303, 'Luxury'),
#  ('Sydney', 'NSW', 2327, 5, 1, 1649045, 'Luxury'),
#  ('Melbourne', 'SA', 3627, 2, 3, 1111644, 'Luxury'),
#  ('Brisbane', 'QLD', 3269, 5, 1, 1327467, 'Luxury'),
#  ('Melbourne', 'WA', 1481, 2, 2, 1314856, 'Luxury'),
#  ('Melbourne', 'WA', 1535, 3, 2, 1013132, 'Luxury'),
#  ('Melbourne', 'QLD', 1181, 4, 3, 1070858, 'Luxury'),
#  ('Brisbane', 'SA', 1329, 4, 1, 1141379, 'Luxury'),
#  ('Sydney', 'VIC', 3786, 4, 1, 1805138, 'Luxury'),
#  ('Brisbane', 'WA', 2880, 1, 1, 1974588, 'Luxury'),
#  ('Sydney', 'VIC', 1722, 5, 3, 1074278, 'Luxury'),
#  ('Sydney', 'WA', 3916, 3, 2, 1547607, 'Luxury'),
#  ('Brisbane', 'NSW', 3827, 2, 2, 1202133, 'Luxury'),
#  ('Melbourne', 'NSW', 2653, 3, 3, 1097113, 'Luxury'),
#  ('Sydney', 'VIC', 2540, 5, 2, 1457241, 'Luxury'),
#  ('Sydney', 'NSW', 3648, 1, 3, 1845771, 'Luxury'),
#  ('Brisbane', 'QLD', 2703, 3, 3, 1549780, 'Luxury'),
#  ('Brisbane', 'NSW', 3584, 5, 2, 1041956, 'Luxury'),
#  ('Brisbane', 'NSW', 1633, 5, 3, 1254597, 'Luxury'),
#  ('Brisbane', 'QLD', 2403, 2, 1, 1897224, 'Luxury'),
#  ('Brisbane', 'VIC', 1077, 4, 3, 1651942, 'Luxury'),
#  ('Brisbane', 'NSW', 1274, 4, 2, 1055360, 'Luxury'),
#  ('Melbourne', 'QLD', 1049, 5, 2, 1938271, 'Luxury'),
#  ('Melbourne', 'VIC', 1242, 4, 2, 1469705, 'Luxury'),
#  ('Melbourne', 'VIC', 2498, 4, 1, 1219672, 'Luxury'),
#  ('Brisbane', 'QLD', 3414, 4, 3, 1580295, 'Luxury'),
#  ('Melbourne', 'SA', 2768, 1, 1, 1212043, 'Luxury'),
#  ('Melbourne', 'VIC', 3434, 1, 3, 1852757, 'Luxury'),
#  ('Melbourne', 'QLD', 2347, 1, 3, 1414634, 'Luxury'),
#  ('Brisbane', 'VIC', 2841, 4, 1, 1366590, 'Luxury'),
#  ('Brisbane', 'NSW', 3566, 5, 1, 1391949, 'Luxury'),
#  ('Melbourne', 'SA', 3951, 1, 3, 1389575, 'Luxury'),
#  ('Sydney', 'VIC', 2831, 2, 3, 1757588, 'Luxury'),
#  ('Sydney', 'QLD', 3401, 1, 3, 1640062, 'Luxury'),
#  ('Brisbane', 'VIC', 3119, 4, 2, 1232360, 'Luxury'),
#  ('Sydney', 'QLD', 2416, 4, 3, 1675918, 'Luxury'),
#  ('Sydney', 'WA', 2848, 2, 1, 1451642, 'Luxury'),
#  ('Sydney', 'VIC', 1125, 2, 3, 1636773, 'Luxury'),
#  ('Brisbane', 'QLD', 1709, 5, 3, 1384148, 'Luxury'),
#  ('Melbourne', 'NSW', 3725, 2, 3, 1993149, 'Luxury'),
#  ('Brisbane', 'NSW', 1782, 4, 2, 1000490, 'Luxury'),
#  ('Sydney', 'NSW', 1916, 4, 1, 1702434, 'Luxury'),
#  ('Melbourne', 'SA', 1333, 3, 3, 1324519, 'Luxury'),
#  ('Melbourne', 'WA', 1358, 5, 3, 1278027, 'Luxury'),
#  ('Melbourne', 'WA', 1580, 2, 3, 1560991, 'Luxury'),
#  ('Brisbane', 'SA', 2326, 5, 1, 1759548, 'Luxury'),
#  ('Brisbane', 'NSW', 3841, 5, 3, 1696850, 'Luxury'),
#  ('Melbourne', 'VIC', 2230, 1, 3, 1759099, 'Luxury'),
#  ('Brisbane', 'WA', 3374, 2, 1, 1982090, 'Luxury'),
#  ('Sydney', 'NSW', 1058, 4, 2, 1047333, 'Luxury'),
#  ('Brisbane', 'WA', 2528, 4, 3, 1739326, 'Luxury'),
#  ('Melbourne', 'SA', 1946, 4, 3, 1395007, 'Luxury'),
#  ('Brisbane', 'WA', 2641, 4, 1, 1740414, 'Luxury'),
#  ('Melbourne', 'NSW', 2478, 4, 3, 1701703, 'Luxury'),
#  ('Melbourne', 'WA', 1801, 3, 2, 1935500, 'Luxury'),
#  ('Sydney', 'VIC', 1358, 2, 3, 1207452, 'Luxury'),
#  ('Brisbane', 'SA', 1328, 1, 2, 1394821, 'Luxury'),
#  ('Sydney', 'NSW', 3994, 1, 3, 1374144, 'Luxury'),
#  ('Brisbane', 'VIC', 3985, 2, 1, 1260443, 'Luxury'),
#  ('Brisbane', 'NSW', 3164, 1, 1, 1683182, 'Luxury'),
#  ('Sydney', 'WA', 2705, 3, 3, 1888899, 'Luxury'),
#  ('Brisbane', 'QLD', 1438, 3, 3, 1629052, 'Luxury'),
#  ('Brisbane', 'QLD', 3743, 4, 2, 1125115, 'Luxury'),
#  ('Sydney', 'QLD', 3749, 2, 1, 1921046, 'Luxury'),
#  ('Melbourne', 'WA', 3995, 5, 1, 1129327, 'Luxury'),
#  ('Brisbane', 'QLD', 2353, 3, 1, 1633720, 'Luxury'),
#  ('Brisbane', 'VIC', 1269, 1, 1, 1397442, 'Luxury'),
#  ('Brisbane', 'QLD', 2181, 1, 1, 1997588, 'Luxury'),
#  ('Brisbane', 'SA', 3487, 4, 2, 1456090, 'Luxury'),
#  ('Brisbane', 'QLD', 1910, 3, 1, 1535759, 'Luxury'),
#  ('Melbourne', 'WA', 810, 2, 2, 1788671, 'Luxury'),
#  ('Melbourne', 'SA', 902, 4, 1, 1760331, 'Luxury'),
#  ('Brisbane', 'QLD', 3482, 2, 3, 1228296, 'Luxury'),
#  ('Melbourne', 'SA', 1672, 4, 3, 1890936, 'Luxury'),
#  ('Melbourne', 'QLD', 1819, 4, 3, 1078120, 'Luxury'),
#  ('Brisbane', 'QLD', 3431, 2, 1, 1780819, 'Luxury'),
#  ('Melbourne', 'WA', 1786, 4, 3, 1139833, 'Luxury'),
#  ('Brisbane', 'WA', 3169, 3, 3, 1266269, 'Luxury'),
#  ('Brisbane', 'VIC', 3057, 2, 2, 1817880, 'Luxury'),
#  ('Melbourne', 'QLD', 2592, 4, 3, 1546144, 'Luxury'),
#  ('Melbourne', 'QLD', 1445, 3, 1, 1956521, 'Luxury'),
#  ('Brisbane', 'SA', 2629, 4, 1, 1035178, 'Luxury'),
#  ('Melbourne', 'WA', 2463, 1, 1, 1615507, 'Luxury'),
#  ('Brisbane', 'VIC', 1874, 4, 2, 1058911, 'Luxury'),
#  ('Melbourne', 'VIC', 1942, 3, 1, 1425171, 'Luxury'),
#  ('Sydney', 'WA', 2625, 1, 2, 1921965, 'Luxury'),
#  ('Brisbane', 'NSW', 1004, 2, 3, 1046485, 'Luxury'),
#  ('Melbourne', 'VIC', 3497, 1, 2, 1157724, 'Luxury'),
#  ('Brisbane', 'SA', 916, 1, 3, 1906535, 'Luxury'),
#  ('Brisbane', 'QLD', 1065, 4, 3, 1700021, 'Luxury'),
#  ('Brisbane', 'WA', 1935, 3, 3, 1891628, 'Luxury'),
#  ('Melbourne', 'VIC', 1025, 2, 1, 1865211, 'Luxury'),
#  ('Melbourne', 'VIC', 1396, 3, 3, 1678237, 'Luxury'),
#  ('Sydney', 'WA', 2580, 4, 1, 1318098, 'Luxury'),
#  ('Brisbane', 'NSW', 3179, 3, 2, 1235620, 'Luxury'),
#  ('Brisbane', 'SA', 1725, 1, 1, 1265967, 'Luxury'),
#  ('Brisbane', 'NSW', 2378, 5, 2, 1197478, 'Luxury'),
#  ('Sydney', 'VIC', 2766, 1, 3, 1098440, 'Luxury'),
#  ('Sydney', 'WA', 3382, 5, 1, 1501567, 'Luxury'),
#  ('Melbourne', 'QLD', 1727, 3, 1, 1745095, 'Luxury'),
#  ('Melbourne', 'NSW', 1885, 4, 1, 1237217, 'Luxury'),
#  ('Sydney', 'WA', 3608, 5, 3, 1862689, 'Luxury'),
#  ('Brisbane', 'SA', 3143, 1, 1, 1328455, 'Luxury'),
#  ('Melbourne', 'WA', 1267, 5, 3, 1621084, 'Luxury'),
#  ('Brisbane', 'SA', 3285, 5, 3, 1163131, 'Luxury'),
#  ('Melbourne', 'VIC', 3007, 1, 3, 1916941, 'Luxury'),
#  ('Brisbane', 'QLD', 2359, 2, 3, 1015231, 'Luxury'),
#  ('Sydney', 'NSW', 3513, 2, 2, 1913900, 'Luxury'),
#  ('Sydney', 'SA', 3636, 1, 2, 1320721, 'Luxury'),
#  ('Brisbane', 'SA', 2272, 4, 2, 1398868, 'Luxury'),
#  ('Melbourne', 'NSW', 2771, 2, 1, 1733727, 'Luxury'),
#  ('Melbourne', 'NSW', 1314, 5, 3, 1811622, 'Luxury'),
#  ('Brisbane', 'QLD', 2678, 4, 1, 1906241, 'Luxury'),
#  ('Melbourne', 'VIC', 1199, 1, 3, 1609023, 'Luxury'),
#  ('Melbourne', 'QLD', 2512, 5, 3, 1539420, 'Luxury'),
#  ('Melbourne', 'WA', 3518, 5, 3, 1833287, 'Luxury'),
#  ('Brisbane', 'SA', 1548, 3, 3, 1599552, 'Luxury'),
#  ('Sydney', 'NSW', 3540, 1, 3, 1902737, 'Luxury'),
#  ('Brisbane', 'VIC', 2292, 3, 3, 1952307, 'Luxury'),
#  ('Brisbane', 'SA', 1873, 3, 1, 1620700, 'Luxury'),
#  ('Melbourne', 'QLD', 3881, 4, 1, 1088807, 'Luxury'),
#  ('Brisbane', 'QLD', 2861, 1, 3, 1167913, 'Luxury'),
#  ('Sydney', 'VIC', 3893, 2, 2, 1831835, 'Luxury'),
#  ('Melbourne', 'SA', 2529, 3, 1, 1483417, 'Luxury'),
#  ('Sydney', 'SA', 3094, 5, 1, 1890690, 'Luxury'),
#  ('Sydney', 'NSW', 2141, 2, 2, 1216741, 'Luxury'),
#  ('Sydney', 'NSW', 2660, 1, 3, 1249083, 'Luxury'),
#  ('Sydney', 'QLD', 2163, 4, 3, 1819131, 'Luxury'),
#  ('Brisbane', 'WA', 1411, 1, 1, 1364414, 'Luxury'),
#  ('Brisbane', 'SA', 1459, 1, 3, 1117131, 'Luxury'),
#  ('Melbourne', 'NSW', 1229, 5, 1, 1504244, 'Luxury'),
#  ('Melbourne', 'SA', 3156, 5, 2, 1180751, 'Luxury'),
#  ('Brisbane', 'WA', 930, 3, 3, 1467180, 'Luxury'),
#  ('Melbourne', 'WA', 845, 5, 2, 1418478, 'Luxury'),
#  ('Sydney', 'SA', 3916, 1, 1, 1070954, 'Luxury'),
#  ('Melbourne', 'SA', 2562, 4, 2, 1149221, 'Luxury'),
#  ('Sydney', 'SA', 2323, 2, 3, 1451237, 'Luxury'),
#  ('Brisbane', 'QLD', 3498, 5, 1, 1177424, 'Luxury'),
#  ('Melbourne', 'NSW', 984, 1, 3, 1800989, 'Luxury'),
#  ('Melbourne', 'QLD', 2492, 1, 3, 1318067, 'Luxury'),
#  ('Brisbane', 'SA', 1079, 3, 3, 1135783, 'Luxury'),
#  ...]

# %%
con.close()

# %% [markdown]
# # Phân tích giá nhà tại các khu vực thành phố lớn

# %%
stats = df_city.describe()
print("Thống kê mô tả tổng quát cho giá bất động sản")
print(stats.to_string(float_format='{:.2f}'.format))
# Out:
# Thống kê mô tả tổng quát cho giá bất động sản
#          SqFt  Bedrooms  Bathrooms      Price
# count 2972.00   2972.00    2972.00    2972.00
# mean  2385.15      2.99       1.98 1056062.95
# std    920.90      1.40       0.81  553218.38
# min    802.00      1.00       1.00  100564.00
# 25%   1583.75      2.00       1.00  582129.50
# 50%   2379.50      3.00       2.00 1053690.00
# 75%   3176.75      4.00       3.00 1539263.25
# max   3998.00      5.00       3.00 1999701.00

# %%
# Độ biến thiên giá theo khu vực
Price_variance_by_location = df_city.groupby('State')['Price'].var()

print(Price_variance_by_location.to_string(float_format='{:.2f}'.format))
# Out:
# State
# NSW   311330252945.55
# QLD   310875433582.29
# SA    291779651529.79
# VIC   301285609404.58
# WA    311248635968.89

# %%
# Số lượng bất động sản theo khu vực

count_by_City = df['City'].value_counts()
count_by_City
# Out:
# City
# Adelaide     1040
# Melbourne    1021
# Brisbane     1007
# Perth         988
# Sydney        944
# Name: count, dtype: int64

# %%
# Hệ số biến thiên giá (coeefficient of variation) 
cv = df_city['Price'].std() / df_city['Price'].mean()
cv
# Out:
# 0.5238498113469865

# %%
# Độ phân tán giá
Price_range = df_city['Price'].max() - df_city['Price'].min()

Price_range
# Out:
# 1899137

# %%
Q1 = df_city['Price'].quantile(0.25)
Q3 = df_city['Price'].quantile(0.75)

IQR = Q3 - Q1 

outliers = df_city[(df_city['Price'] < (Q1 - 1.5 * IQR)) | (df_city['Price'] > (Q3 + 1.5 * IQR))]

outliers
# Out:
# Empty DataFrame
# Columns: [City, State, SqFt, Bedrooms, Bathrooms, Price, PriceSegment]
# Index: []

# %%
# Độ lệch trung bình tuyệt đối (mean absolute deviation)
Price_data = df_city['Price']
mean_Price = Price_data.mean()

mad = (Price_data - mean_Price).abs().mean()

mad
# Out:
# 479147.163494092

# %%
# Tần suất xuất hiện của giá (frequency analysis)
frequency = df_city['PriceSegment'].value_counts()
frequency
# Out:
# PriceSegment
# Luxury        1568
# High-end      1404
# Affordable       0
# Mid-range        0
# Name: count, dtype: int64

# %%
# Hệ số tương quan giữa gía và diện tích
corr_Price_area = df_city['Price'].corr(df_city['SqFt'])
corr_Price_area
# Out:
# -0.011602838067318356

# %%
# Hệ số tương quan giữa giá và phòng ngủ
corr_Price_Bedrooms = df_city['Price'].corr(df_city['Bedrooms'])
corr_Price_Bedrooms
# Out:
# -0.008964668396868512

# %%
# Hệ số tương quan giữa vùng 
mean_Price_by_location = df_city.groupby('State')['Price'].mean()
print(mean_Price_by_location.to_string(float_format='{:.2f}'.format))
# Out:
# State
# NSW   1051016.26
# QLD   1027178.77
# SA    1046833.75
# VIC   1035296.20
# WA    1117958.15

# %%
outliers_upper = df_city[df_city['Price'] > (Q3 + 1.5 * IQR)]
outliers_lower = df_city[df_city['Price'] < (Q1 - 1.5 * IQR)]
print(f'Outliers upper : {outliers_upper}')
print(f'Outliers lower : {outliers_lower}')
# Out:
# Outliers upper : Empty DataFrame
# Columns: [City, State, SqFt, Bedrooms, Bathrooms, Price, PriceSegment]
# Index: []
# Outliers lower : Empty DataFrame
# Columns: [City, State, SqFt, Bedrooms, Bathrooms, Price, PriceSegment]
# Index: []

# %%
Price_quantiles = df_city['Price'].quantile([0.25,0.5,0.7,1.0])
Price_quantiles
# Out:
# 0.25     582129.5
# 0.50    1053690.0
# 0.70    1435183.1
# 1.00    1999701.0
# Name: Price, dtype: float64

# %% [markdown]
# # Data Visualization

# %%
df_city.head()
# Out:
#         City State  SqFt  Bedrooms  Bathrooms    Price PriceSegment
# 1  Melbourne   VIC  3735         3          2   571388     High-end
# 2     Sydney   VIC  2032         5          1   866821     High-end
# 3   Brisbane    SA  3861         4          3  1230977       Luxury
# 5   Brisbane    SA  1923         4          2   631871     High-end
# 7   Brisbane   QLD  2447         1          1  1509971       Luxury

# %%
average_State = df_city.groupby('City')['Price'].mean()

plt.figure(figsize =(12,6))
sns.barplot(x =average_State.index, y =average_State.values, color = 'green')

yticks = plt.yticks()[0]
plt.yticks(yticks, labels=[f'{float(tick)/(1):,.1f}' for tick in yticks])

plt.title('Giá trung bình giữa các khu vực thành phố lớn')
plt.xlabel('Bang')
plt.ylabel('Giá BĐS trung bình (USD')
# Out:
# Text(0, 0.5, 'Giá BĐS trung bình (USD')

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x = 'City', y = 'Price', data = df_city, color = 'Green')

yticks = plt.yticks()[0]
plt.yticks(yticks, labels=[f'{float(tick)/(1):,.1f}' for tick in yticks])


plt.title('Phân phối giá ở các khu du lịch khác nhau')
plt.xlabel('Khu vực')
plt.ylabel('USD')
# Out:
# Text(0, 0.5, 'USD')

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='State', y='Price', data=df_city)

yticks = plt.yticks()[0]
plt.yticks(yticks, labels=[f'{float(tick)/(10*(1)):,.1f}' for tick in yticks])

plt.title('Phân tích sự phân tán giá')
plt.xlabel('Tỉnh thành')
plt.ylabel('Tỉ VND')
;
# Out:
# ''

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(x='Bedrooms', y='Price', data=df_city, alpha=0.5)

yticks = plt.yticks()[0]
plt.yticks(yticks,label = [f'{float(tick) / (10):,.1f}' for tick in yticks])

plt.title('Quan hệ giữa giá và phòng ngủ')

plt.xlabel('Số phòng ngủ')
plt.ylabel('Giá USD')
# Out:
# Text(0, 0.5, 'Giá USD')

# %%
real_eState_counts = df_city['City'].value_counts()

plt.figure(figsize = (12,6))
plt.pie(real_eState_counts, labels = real_eState_counts.index, autopct ='%1.1f%%', startangle = 140);

# %%
plt.figure(figsize=(12, 10))
sns.histplot(df_city['Price'], kde=True, color='blue',bins = 200)

xticks = plt.xticks()[0]
plt.xticks(xticks, labels=[f'{float(tick):,.1f}' for tick in xticks])
plt.xlim(0)
plt.xlim(0,2000000)

plt.title('Phân phối giá của bất động sản')
plt.xlabel('USD')
plt.ylabel('Số lượng');

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_city['Price'], kde=True, color='blue', cumulative=True, bins=200)

xticks = plt.xticks()[0]
plt.xticks(xticks, labels=[f'{float(tick):,.1f}' for tick in xticks])
plt.xlim(0,2000000)

plt.title('Phân phối tích lũy giá của bất động sản')
plt.xlabel('USD')
plt.ylabel('Số lượng');

# %%
# Heatmap: Tương quan giữa giá và các yếu tố khác.
corr_matrix = df_city[['Price', 'SqFt','Bedrooms', 'Bathrooms']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=0.5);

# %%
sns.pairplot(df_city[['Price', 'SqFt','Bedrooms', 'Bathrooms']]);

# %%
sns.kdeplot(df_city['Price'], color='blue', fill=True)

xticks = plt.xticks()[0]
plt.xticks(xticks, labels=[f'{float(tick):,.1f}' for tick in xticks])
plt.xlim(0)

plt.xlabel('USD');

# %%
sns.lineplot(data=df_city['Price'], color='blue')
plt.fill_between(df_city.index, df_city['Price'], color='blue', alpha=0.3)

yticks = plt.yticks()[0]
plt.yticks(yticks, labels=[f'{float(tick):,.1f}' for tick in yticks])

plt.title('Xu hướng giá')
plt.xlabel('Index')
plt.ylabel('USD')
;
# Out:
# ''

# %%
Price_billion = df_city['Price'].apply(lambda x: x/(10))

sns.scatterplot(x=df_city.SqFt, y=Price_billion, size=Price_billion, sizes=(20, 200), alpha=0.5)

plt.title('Biểu đồ bong bóng của giá bất động sản theo diện tích')
plt.xlabel('Area (m2)')
plt.ylabel(' USD')

plt.legend(title='USD', fontsize='10')

;
# Out:
# ''

# %%
# Huấn luyện mô hình
X = df_city[['SqFt', 'Bedrooms', 'Bathrooms']]
Y = df_city[['Price']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train, Y_train)
Price_predictions = model.predict(X_test)

# %%
# Visualize khả năng dự đoán
plt.scatter(x=Price_predictions, y=Y_test.values, alpha=0.5)
plt.plot(Y_test.values, Y_test.values, color='red', label='Ideal Line')

plt.ylabel('Predicted Price ( USD)')
plt.xlabel('Actual Price ( Nghìn USD)')
plt.legend()

xticks = plt.xticks()[0]
plt.xticks(xticks, labels=[f'{float(tick)/(10**3):,.1f}' for tick in xticks])

yticks = plt.yticks()[0]
plt.yticks(yticks, labels=[f'{float(tick):,.1f}' for tick in yticks]);
